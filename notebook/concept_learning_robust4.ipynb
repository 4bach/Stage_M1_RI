# %% [markdown]
# # Learning concept representation with Word2Vec

# %% [markdown]
# With the objective of improving the DRMM neural architecture for a classic ad-hoc Information Retrieval problem.
# Using the Robust4 dataset and the concept build with Wordnet : http://wordnetweb.princeton.edu/perl/webwn
#
#
# Theses two tutorials helped me to achieve it.
#
# https://github.com/llSourcell/word_vectors_game_of_thrones-LIVE/blob/master/Thrones2Vec.ipynb
#
# https://rare-technologies.com/word2vec-tutorial/

# %%
from __future__ import absolute_import, division, print_function
import codecs 
import glob 
import logging 
import multiprocessing
import os 
import pprint
import re
import ast
import json
import operator
import collections

# %%
import nltk 
import gensim.models.word2vec as w2v 
import sklearn.manifold # dimensionality reduction for visualisation.
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns
from bs4 import BeautifulSoup
from gensim.parsing.preprocessing import preprocess_string,remove_stopwords,strip_numeric, strip_tags, strip_punctuation

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Loading data

# %%
def load_all_path_docs_robust4(folder="/local/karmim/Stage_M1_RI/data/annotated_collection_tagme_score/015"):
        """
            We load all the path of all the annotated document of the robust4 collection.
        """
        
        all_file_name =[]
        for r,_,f in os.walk(folder): 
            for file in f: 
                all_file_name.append(os.path.join(r,file))
        return all_file_name

# %%
all_file_name = load_all_path_docs_robust4()
print("There is",len(all_file_name),"files in the collection")
# Out:
# There is 2295 files in the collection

# %%
all_file_name[0]
# Out:
# '/local/karmim/Stage_M1_RI/data/annotated_collection_tagme_score/015/FR94/10/FR941003.2'

# %%
def load_all_query_annotated_robust4(file = '/local/karmim/Stage_M1_RI/data/topics-title.annotated.csv',pre_process=True,CUSTOM_FILTERS=[lambda x: x.lower(),remove_stopwords],delete_meaning=False):
    query_an = {} # Dict with words and concept for a query id
    concept = {} # Dict with only the concept for a query id
    f = codecs.open(file,'r',encoding='utf-8',errors='ignore')
    for line in f: 
        #print(line.split())
        line = np.array(line.split())
        index = np.where(np.char.find(line, '$#')>=0)
        concept[line[0]] = list(line[index])
        query_an[line[0]] = list(line[1:])
        
        if delete_meaning : 
            concept[line[0]] = [ w[:-5] for w in concept[line[0]] ]
            query_an[line[0]] = [w[:-5] if '$#' in w else w for w in query_an[line[0]] ]
        if pre_process:
            for k in query_an : 
                query_an[k] = preprocess_string(' '.join(query_an[k]),CUSTOM_FILTERS)
                concept[k] = preprocess_string(' '.join(concept[k]),[lambda x : x.lower()]) 
            
    return query_an,concept

# %%
q,c = load_all_query_annotated_robust4(delete_meaning=True)

# %%
q['301']
# Out:
# ['international', '$#!international', 'organized', 'crime', '$#!crime']

# %%
c['301']
# Out:
# ['$#!international', '$#!crime']

# %%
q
# Out:
# {'301': ['international',
#   '$#!international',
#   'organized',
#   'crime',
#   '$#!crime'],
#  '302': ['poliomyelitis',
#   '$#!poliomyelitis',
#   'post',
#   '$#!post',
#   'polio',
#   '$#!poliomyelitis'],
#  '303': ['hubble',
#   'telescope',
#   '$#!telescope',
#   'achievements',
#   '$#!accomplishment'],
#  '304': ['endangered', 'species', '$#!species', 'mammals', '$#!mammal'],
#  '305': ['dangerous', 'vehicles', '$#!vehicle'],
#  '306': ['african', 'civilian', '$#!civilian', 'deaths', '$#!end'],
#  '307': ['new', 'hydroelectric', 'projects', '$#!undertaking'],
#  '308': ['implant', 'dentistry', '$#!dentistry'],
#  '309': ['rap', '$#!rap', 'crime', '$#!crime'],
#  '310': ['radio',
#   '$#!radio',
#   'waves',
#   '$#!wave',
#   'brain',
#   '$#!mind',
#   'cancer',
#   '$#!cancer'],
#  '311': ['industrial', 'espionage', '$#!espionage'],
#  '312': ['hydroponics', '$#!hydroponics'],
#  '313': ['magnetic',
#   'levitation',
#   '$#!levitation',
#   'maglev',
#   '$#!magnetic_levitation'],
#  '314': ['marine', '$#!marine', 'vegetation', '$#!vegetation'],
#  '315': ['unexplained', 'highway', '$#!highway', 'accidents', '$#!accident'],
#  '316': ['polygamy',
#   '$#!polygamy',
#   'polyandry',
#   '$#!polyandry',
#   'polygyny',
#   '$#!polygyny'],
#  '317': ['unsolicited', 'faxes', '$#!facsimile'],
#  '318': ['best',
#   '$#!best',
#   'retirement',
#   '$#!retirement',
#   'country',
#   '$#!state'],
#  '319': ['new', 'fuel', '$#!fuel', 'sources', '$#!source'],
#  '320': ['undersea',
#   'fiber',
#   '$#!fiber',
#   'optic',
#   '$#!eye',
#   'cable',
#   '$#!cable'],
#  '321': ['women', '$#!womanhood', 'parliaments', '$#!parliament'],
#  '322': ['international',
#   '$#!international',
#   'art',
#   '$#!artwork',
#   'crime',
#   '$#!crime'],
#  '323': ['literary', 'journalistic', 'plagiarism', '$#!plagiarism'],
#  '324': ['argentine',
#   '$#!argentine',
#   'british',
#   'relations',
#   '$#!sexual_intercourse'],
#  '325': ['cult', '$#!fad', 'lifestyles', '$#!life_style'],
#  '326': ['ferry', '$#!ferry', 'sinkings', '$#!sinking'],
#  '327': ['modern', 'slavery', '$#!slavery'],
#  '328': ['pope', '$#!pope', 'beatifications', '$#!blessedness'],
#  '329': ['mexican',
#   '$#!mexican',
#   'air',
#   '$#!tune',
#   'pollution',
#   '$#!pollution'],
#  '330': ['iran',
#   '$#!iran',
#   'iraq',
#   '$#!iraq',
#   'cooperation',
#   '$#!cooperation'],
#  '331': ['world',
#   '$#!world',
#   'bank',
#   '$#!savings_bank',
#   'criticism',
#   '$#!criticism'],
#  '332': ['income', 'tax', '$#!tax', 'evasion', '$#!evasion'],
#  '333': ['antibiotics',
#   '$#!antibiotic',
#   'bacteria',
#   '$#!bacteria',
#   'disease',
#   '$#!disease'],
#  '334': ['export',
#   '$#!export',
#   'controls',
#   '$#!control_condition',
#   'cryptography',
#   '$#!cryptography'],
#  '335': ['adoptive', 'biological', 'parents', '$#!parent'],
#  '336': ['black', '$#!black', 'bear', '$#!bear', 'attacks', '$#!attack'],
#  '337': ['viral', 'hepatitis', '$#!hepatitis'],
#  '338': ['risk', '$#!risk', 'aspirin', '$#!aspirin'],
#  '339': ['alzheimer', 's', 'drug', '$#!drug', 'treatment', '$#!treatment'],
#  '340': ['land', '$#!state', '$#!mine', 'ban', '$#!prohibition'],
#  '341': ['airport', '$#!airport', 'security', '$#!security_system'],
#  '342': ['diplomatic', 'expulsion', '$#!extrusion'],
#  '343': ['police', '$#!police', 'deaths', '$#!end'],
#  '344': ['abuses', '$#!abuse', 'e', '$#!vitamin_e', 'mail', '$#!mail'],
#  '345': ['overseas', 'tobacco', '$#!tobacco', 'sales', '$#!sale'],
#  '346': ['educational', 'standards', '$#!standard'],
#  '347': ['wildlife', '$#!wildlife', 'extinction', '$#!extinction'],
#  '348': ['agoraphobia', '$#!agoraphobia'],
#  '349': ['metabolism', '$#!metamorphosis'],
#  '350': ['health', '$#!health', '$#!computer', 'terminals', '$#!terminal'],
#  '351': ['falkland',
#   'petroleum',
#   '$#!petroleum',
#   'exploration',
#   '$#!exploration'],
#  '352': ['british', 'chunnel', '$#!chunnel', 'impact', '$#!impact'],
#  '353': ['antarctica', '$#!antarctica', 'exploration', '$#!exploration'],
#  '354': ['journalist', '$#!journalist', 'risks', '$#!risk'],
#  '355': ['ocean', 'remote', 'sensing'],
#  '356': ['postmenopausal',
#   'estrogen',
#   '$#!estrogen',
#   'britain',
#   '$#!united_kingdom'],
#  '357': ['territorial', 'waters', '$#!water_system', 'dispute'],
#  '358': ['blood',
#   '$#!rake',
#   'alcohol',
#   '$#!alcohol',
#   'fatalities',
#   '$#!fatality'],
#  '359': ['mutual', 'fund', '$#!store', 'predictors', '$#!predictor'],
#  '360': ['drug',
#   '$#!drug',
#   'legalization',
#   '$#!legalization',
#   'benefits',
#   '$#!benefit'],
#  '361': ['clothing', '$#!clothing', 'sweatshops', '$#!sweatshop'],
#  '362': ['human', 'smuggling'],
#  '363': ['transportation',
#   '$#!transportation_system',
#   'tunnel',
#   '$#!tunnel',
#   'disasters',
#   '$#!catastrophe'],
#  '364': ['rabies', '$#!rabies'],
#  '365': ['el', '$#!elevation', 'nino'],
#  '366': ['commercial', 'cyanide', '$#!nitrile', 'uses', '$#!use'],
#  '367': ['piracy', '$#!piracy'],
#  '368': ['vitro', 'fertilization', '$#!fertilization'],
#  '369': ['anorexia', '$#!anorexia', 'nervosa', 'bulimia', '$#!bulimia'],
#  '370': ['food', '$#!food', 'drug', '$#!drug', 'laws', '$#!torah'],
#  '371': ['health', '$#!health', 'insurance', '$#!policy', 'holistic'],
#  '372': ['native', 'american', '$#!american', 'casino', '$#!casino'],
#  '373': ['encryption',
#   '$#!encoding',
#   'equipment',
#   '$#!equipment',
#   'export',
#   '$#!export'],
#  '374': ['nobel', '$#!nobel', 'prize', '$#!trophy', 'winners', '$#!winner'],
#  '375': ['hydrogen', '$#!hydrogen', 'energy', '$#!energy'],
#  '376': ['world', '$#!worldly_concern', 'court', '$#!motor_hotel'],
#  '377': ['cigar', '$#!cigar', 'smoking', '$#!smoke'],
#  '378': ['euro', 'opposition', '$#!resistance'],
#  '379': ['mainstreaming'],
#  '380': ['obesity', '$#!fleshiness', 'medical', 'treatment', '$#!treatment'],
#  '381': ['alternative', 'medicine', '$#!medicine'],
#  '382': ['hydrogen',
#   '$#!hydrogen',
#   'fuel',
#   '$#!fuel',
#   'automobiles',
#   '$#!car'],
#  '383': ['mental', 'illness', '$#!illness', 'drugs', '$#!drug'],
#  '384': ['space', '$#!space', 'station', '$#!station', 'moon', '$#!moon'],
#  '385': ['hybrid', 'fuel', '$#!fuel', 'cars', '$#!car'],
#  '386': ['teaching', 'disabled', 'children', '$#!child'],
#  '387': ['radioactive', 'waste', '$#!waste'],
#  '388': ['organic', 'soil', '$#!territory', 'enhancement', '$#!enhancement'],
#  '389': ['illegal', 'technology', '$#!technology', 'transfer', '$#!transfer'],
#  '390': ['orphan', '$#!orphan', 'drugs', '$#!drug'],
#  '391': ['r',
#   '$#!gas_constant',
#   'd',
#   '$#!vitamin_d',
#   'drug',
#   '$#!drug',
#   'prices',
#   '$#!price'],
#  '392': ['robotics', '$#!robotics'],
#  '393': ['mercy', '$#!mercy', 'killing'],
#  '394': ['home', '$#!home_plate', 'schooling', '$#!schooling'],
#  '395': ['tourism', '$#!tourism'],
#  '396': ['sick', 'building', '$#!construction', 'syndrome', '$#!syndrome'],
#  '397': ['automobile', '$#!car', 'recalls', '$#!recall'],
#  '398': ['dismantling', 'europe', '$#!europe', 's', 'arsenal'],
#  '399': ['oceanographic', 'vessels', '$#!vessel'],
#  '400': ['amazon', '$#!amazon', 'rain', '$#!rain', 'forest', '$#!forest'],
#  '401': ['foreign', 'minorities', '$#!minority', 'germany', '$#!germany'],
#  '402': ['behavioral', 'genetics', '$#!genetics'],
#  '403': ['osteoporosis', '$#!osteoporosis'],
#  '404': ['ireland', '$#!ireland', 'peace', '$#!peace', 'talks', '$#!talk'],
#  '405': ['cosmic', 'events', '$#!event'],
#  '406': ['parkinson', '$#!parkinson', 's', 'disease', '$#!disease'],
#  '407': ['poaching', 'wildlife', '$#!wildlife', 'preserves', '$#!preserve'],
#  '408': ['tropical', 'storms', '$#!storm'],
#  '409': ['legal', 'pan', '$#!pan', '103'],
#  '410': ['schengen', 'agreement', '$#!agreement'],
#  '411': ['salvaging', 'shipwreck', '$#!shipwreck', 'treasure', '$#!treasure'],
#  '412': ['airport', '$#!airport', 'security', '$#!security'],
#  '413': ['steel', '$#!sword', 'production', '$#!production'],
#  '414': ['cuba', '$#!cuba', 'sugar', '$#!sugar', 'exports', '$#!export'],
#  '415': ['drugs', '$#!drug', 'golden', 'triangle', '$#!triangulum'],
#  '416': ['gorges', '$#!gorge', 'project', '$#!undertaking'],
#  '417': ['creativity', '$#!creativity'],
#  '418': ['quilts', '$#!quilt', 'income', '$#!income'],
#  '419': ['recycle', 'automobile', '$#!car', 'tires', '$#!tire'],
#  '420': ['carbon',
#   '$#!carbon_paper',
#   'monoxide',
#   '$#!monoxide',
#   'poisoning',
#   '$#!poisoning'],
#  '421': ['industrial', 'waste', '$#!waste', 'disposal', '$#!disposal'],
#  '422': ['art', '$#!artwork', 'stolen', 'forged'],
#  '423': ['milosevic', 'mirjana', 'markovic'],
#  '424': ['suicides', '$#!suicide'],
#  '425': ['counterfeiting', 'money', '$#!money'],
#  '426': ['law', '$#!law', 'enforcement', '$#!enforcement', 'dogs', '$#!pawl'],
#  '427': ['uv', '$#!ultraviolet', 'damage', '$#!wrong', 'eyes', '$#!eye'],
#  '428': ['declining', 'birth', '$#!birth', 'rates', '$#!rates'],
#  '429': ['legionnaires', '$#!legionnaire', 'disease'],
#  '430': ['killer', '$#!killer', 'bee', '$#!bee', 'attacks', '$#!attack'],
#  '431': ['robotic', 'technology', '$#!technology'],
#  '432': ['profiling', 'motorists', '$#!motorist', 'police', '$#!police'],
#  '433': ['greek', 'philosophy', '$#!philosophy', 'stoicism', '$#!stoicism'],
#  '434': ['estonia', '$#!estonia', 'economy', '$#!economy'],
#  '435': ['curbing', 'population', '$#!population', 'growth', '$#!increase'],
#  '436': ['railway', '$#!railway', 'accidents', '$#!accident'],
#  '437': ['deregulation',
#   '$#!deregulation',
#   'gas',
#   '$#!natural_gas',
#   'electric',
#   '$#!electric'],
#  '438': ['tourism', '$#!tourism', 'increase', '$#!increase'],
#  '439': ['inventions',
#   '$#!invention',
#   'scientific',
#   'discoveries',
#   '$#!discovery'],
#  '440': ['child', '$#!child', 'labor', '$#!parturiency'],
#  '441': ['lyme', 'disease', '$#!disease'],
#  '442': ['heroic', '$#!heroic_verse', 'acts', '$#!acts_of_the_apostles'],
#  '443': ['u',
#   '$#!uranium',
#   's',
#   '$#!second',
#   'investment',
#   '$#!investment',
#   'africa',
#   '$#!africa'],
#  '444': ['supercritical', 'fluids', '$#!fluid'],
#  '445': ['women', '$#!womanhood', 'clergy'],
#  '446': ['tourists', '$#!tourist', 'violence', '$#!violence'],
#  '447': ['stirling', 'engine', '$#!locomotive'],
#  '448': ['ship', '$#!ship', 'losses', '$#!personnel_casualty'],
#  '449': ['antibiotics',
#   '$#!antibiotic',
#   'ineffectiveness',
#   '$#!ineffectiveness'],
#  '450': ['king', 'hussein', '$#!hussein', 'peace', '$#!peace'],
#  '601': ['turkey', '$#!turkey', 'iraq', '$#!iraq', 'water', '$#!water_system'],
#  '602': ['czech',
#   '$#!czechoslovakian',
#   'slovak',
#   '$#!slovak',
#   'sovereignty',
#   '$#!sovereignty'],
#  '603': ['tobacco',
#   '$#!tobacco',
#   'cigarette',
#   '$#!cigarette',
#   'lawsuit',
#   '$#!lawsuit'],
#  '604': ['lyme', 'disease', '$#!disease', 'arthritis', '$#!arthritis'],
#  '605': ['great',
#   '$#!great',
#   'britain',
#   '$#!united_kingdom',
#   'health',
#   '$#!health',
#   'care',
#   '$#!care'],
#  '606': ['leg', '$#!stage', 'traps', '$#!trap', 'ban'],
#  '607': ['human', 'genetic', 'code', '$#!code'],
#  '608': ['taxing', 'social', 'security', '$#!security'],
#  '609': ['capita',
#   '$#!caput',
#   'alcohol',
#   '$#!alcohol',
#   'consumption',
#   '$#!pulmonary_tuberculosis'],
#  '610': ['minimum', 'wage', '$#!wage', 'adverse', 'impact', '$#!impact'],
#  '611': ['kurds',
#   '$#!kurd',
#   'germany',
#   '$#!germany',
#   'violence',
#   '$#!violence'],
#  '612': ['tibet', '$#!tibet', 'protesters', '$#!dissenter'],
#  '613': ['berlin', '$#!berlin', 'wall', '$#!wall', 'disposal', '$#!disposal'],
#  '614': ['flavr', 'savr', 'tomato', '$#!tomato'],
#  '615': ['timber', '$#!timbre', 'exports', '$#!export', 'asia'],
#  '616': ['volkswagen', 'mexico', '$#!mexico'],
#  '617': ['russia',
#   '$#!soviet_union',
#   'cuba',
#   '$#!cuba',
#   'economy',
#   '$#!economy'],
#  '618': ['ayatollah',
#   '$#!ayatollah',
#   'khomeini',
#   '$#!khomeini',
#   'death',
#   '$#!end'],
#  '619': ['winnie', 'mandela', '$#!mandela', 'scandal', '$#!scandal'],
#  '620': ['france', '$#!france', 'nuclear', 'testing', '$#!examination'],
#  '621': ['women',
#   '$#!womanhood',
#   'ordained',
#   'church',
#   '$#!church_service',
#   'england',
#   '$#!england'],
#  '622': ['price', '$#!price', 'fixing', '$#!repair'],
#  '623': ['toxic', 'chemical', '$#!chemical', 'weapon', '$#!weapon'],
#  '624': ['sdi', 'star', '$#!star_topology', 'wars', '$#!war'],
#  '625': ['arrests',
#   '$#!apprehension',
#   'bombing',
#   'wtc',
#   '$#!world_trade_center'],
#  '626': ['human', 'stampede', '$#!stampede'],
#  '627': ['russian', 'food', '$#!food', 'crisis', '$#!crisis'],
#  '628': ['u',
#   '$#!uranium',
#   's',
#   '$#!second',
#   'invasion',
#   '$#!invasion',
#   'panama',
#   '$#!panama'],
#  '629': ['abortion', '$#!miscarriage', 'clinic', 'attack', '$#!attack'],
#  '630': ['gulf', '$#!gulf', 'war', '$#!war', 'syndrome', '$#!syndrome'],
#  '631': ['mandela',
#   '$#!mandela',
#   'south',
#   '$#!south',
#   'africa',
#   '$#!africa',
#   'president',
#   '$#!president'],
#  '632': ['southeast',
#   'asia',
#   '$#!asia',
#   'tin',
#   '$#!tin',
#   'mining',
#   '$#!mining'],
#  '633': ['welsh', '$#!welshman', 'devolution', '$#!devolution'],
#  '634': ['l', '$#!liter', 'tryptophan', 'deaths', '$#!end'],
#  '635': ['doctor',
#   '$#!doctor_of_the_church',
#   'assisted',
#   'suicides',
#   '$#!suicide'],
#  '636': ['jury', '$#!jury', 'duty', '$#!duty', 'exemptions', '$#!exemption'],
#  '637': ['human', 'growth', '$#!increase', 'hormone', '$#!hormone', 'hgh'],
#  '638': ['wrongful', 'convictions', '$#!conviction'],
#  '639': ['consumer',
#   '$#!consumer',
#   'line',
#   '$#!wrinkle',
#   'shopping',
#   '$#!shopping'],
#  '640': ['maternity', '$#!pregnancy', 'leave', 'policies', '$#!policy'],
#  '641': ['valdez',
#   '$#!valdez',
#   'wildlife',
#   '$#!wildlife',
#   'marine',
#   '$#!marine',
#   'life',
#   '$#!life_sentence'],
#  '642': ['tiananmen', 'square', '$#!square', 'protesters', '$#!dissenter'],
#  '643': ['salmon',
#   'dams',
#   '$#!decameter',
#   'pacific',
#   '$#!pacific',
#   'northwest'],
#  '644': ['exotic', 'animals', '$#!animal', 'import', '$#!significance'],
#  '645': ['software', '$#!software', 'piracy', '$#!piracy'],
#  '646': ['food', '$#!food', 'stamps', '$#!stamp', 'increase', '$#!increase'],
#  '647': ['windmill', '$#!windmill', 'electricity', '$#!electricity'],
#  '648': ['family', '$#!syndicate', 'leave', 'law', '$#!law'],
#  '649': ['$#!computer', 'viruses', '$#!virus'],
#  '650': ['tax', '$#!tax', 'evasion', '$#!evasion', 'indicted'],
#  '651': ['u',
#   '$#!uranium',
#   's',
#   '$#!second',
#   'ethnic',
#   'population',
#   '$#!population'],
#  '652': ['oic', 'balkans', '1990s'],
#  '653': ['eta',
#   '$#!basque_homeland_and_freedom',
#   'basque',
#   '$#!basque',
#   'terrorism',
#   '$#!terrorism'],
#  '654': ['sex', '$#!sexual_activity', 'schools', '$#!school'],
#  '655': ['add',
#   '$#!attention_deficit_disorder',
#   'diagnosis',
#   '$#!diagnosis',
#   'treatment',
#   '$#!treatment'],
#  '656': ['lead',
#   '$#!star',
#   'poisoning',
#   '$#!poisoning',
#   'children',
#   '$#!child'],
#  '657': ['school', '$#!school', 'prayer', '$#!prayer', 'banned'],
#  '658': ['teenage', 'pregnancy', '$#!pregnancy'],
#  '659': ['cruise', '$#!cruise', 'health', '$#!health', 'safety', '$#!safety'],
#  '660': ['whale', 'watching', 'california', '$#!california'],
#  '661': ['melanoma',
#   '$#!melanoma',
#   'treatment',
#   '$#!treatment',
#   'causes',
#   '$#!lawsuit'],
#  '662': ['telemarketer', 'protection', '$#!protective_covering'],
#  '663': ['agent',
#   '$#!agent',
#   'orange',
#   '$#!orange',
#   'exposure',
#   '$#!photograph'],
#  '664': ['american',
#   '$#!american',
#   'indian',
#   '$#!indian',
#   'museum',
#   '$#!museum'],
#  '665': ['poverty',
#   '$#!poverty',
#   'africa',
#   '$#!africa',
#   'sub',
#   'sahara',
#   '$#!sahara'],
#  '666': ['thatcher',
#   '$#!thatcher',
#   'resignation',
#   '$#!resignation',
#   'impact',
#   '$#!impact'],
#  '667': ['unmarried', 'partner', '$#!spouse', 'households', '$#!family'],
#  '668': ['poverty', '$#!poverty', 'disease', '$#!disease'],
#  '669': ['islamic', 'revolution', '$#!rotation'],
#  '670': ['u',
#   '$#!uranium',
#   's',
#   '$#!second',
#   'elections',
#   '$#!election',
#   'apathy'],
#  '671': ['salvation',
#   '$#!salvation',
#   'army',
#   '$#!army',
#   'benefits',
#   '$#!benefit'],
#  '672': ['nra',
#   '$#!national_rifle_association',
#   'membership',
#   '$#!membership',
#   'profile',
#   '$#!visibility'],
#  '673': ['soviet',
#   'withdrawal',
#   '$#!withdrawal',
#   'afghanistan',
#   '$#!afghanistan'],
#  '674': ['greenpeace', '$#!greenpeace', 'prosecuted'],
#  '675': ['olympics',
#   '$#!olympic_games',
#   'training',
#   'swimming',
#   '$#!swimming'],
#  '676': ['poppy', 'cultivation', '$#!polish'],
#  '677': ['leaning', 'tower', '$#!tugboat', 'pisa', '$#!pisa'],
#  '678': ['joint', 'custody', '$#!hands', 'impact', '$#!impact'],
#  '679': ['opening', 'adoption', '$#!adoption', 'records', '$#!record'],
#  '680': ['immigrants', '$#!immigrant', 'spanish', 'school', '$#!school'],
#  '681': ['wind',
#   '$#!wind_instrument',
#   'power',
#   '$#!world_power',
#   'location',
#   '$#!placement'],
#  '682': ['adult', '$#!adult', 'immigrants', '$#!immigrant', 'english'],
#  '683': ['czechoslovakia', '$#!czechoslovakia', 'breakup', '$#!dissolution'],
#  '684': ['$#!part', 'time', '$#!time', 'benefits', '$#!benefit'],
#  '685': ['oscar',
#   '$#!academy_award',
#   'winner',
#   '$#!winner',
#   'selection',
#   '$#!survival'],
#  '686': ['argentina', '$#!argentina', 'pegging', 'dollar', '$#!dollar'],
#  '687': ['northern',
#   '$#!northern',
#   'ireland',
#   '$#!ireland',
#   'industry',
#   '$#!industry'],
#  '688': ['non',
#   'u',
#   '$#!uranium',
#   's',
#   '$#!second',
#   'media',
#   '$#!medium',
#   'bias',
#   '$#!diagonal'],
#  '689': ['family', '$#!syndicate', 'planning', '$#!planning', 'aid', '$#!aid'],
#  '690': ['college',
#   '$#!college',
#   'education',
#   '$#!education',
#   'advantage',
#   '$#!advantage'],
#  '691': ['clear', 'cutting', '$#!film_editing', 'forests', '$#!forest'],
#  '692': ['prostate',
#   '$#!prostate_gland',
#   'cancer',
#   '$#!cancer',
#   'detection',
#   '$#!signal_detection',
#   'treatment',
#   '$#!treatment'],
#  '693': ['newspapers', '$#!newspaper', 'electronic', 'media', '$#!medium'],
#  '694': ['compost', '$#!compost', 'pile', '$#!voltaic_pile'],
#  '695': ['white',
#   'collar',
#   '$#!collar',
#   'crime',
#   '$#!crime',
#   'sentence',
#   '$#!sentence'],
#  '696': ['safety',
#   '$#!safety',
#   'plastic',
#   '$#!credit_card',
#   'surgery',
#   '$#!surgery'],
#  '697': ['air',
#   '$#!tune',
#   'traffic',
#   '$#!traffic',
#   'controller',
#   '$#!restrainer'],
#  '698': ['literacy',
#   '$#!literacy',
#   'rates',
#   '$#!rates',
#   'africa',
#   '$#!africa'],
#  '699': ['term', '$#!terminus', 'limits', '$#!terminus_ad_quem'],
#  '700': ['gasoline',
#   '$#!gasoline',
#   'tax',
#   '$#!tax',
#   'u',
#   '$#!uranium',
#   's',
#   '$#!second']}

# %%
c
# Out:
# {'301': ['$#!international', '$#!crime'],
#  '302': ['$#!poliomyelitis', '$#!post', '$#!poliomyelitis'],
#  '303': ['$#!telescope', '$#!accomplishment'],
#  '304': ['$#!species', '$#!mammal'],
#  '305': ['$#!vehicle'],
#  '306': ['$#!civilian', '$#!end'],
#  '307': ['$#!undertaking'],
#  '308': ['$#!dentistry'],
#  '309': ['$#!rap', '$#!crime'],
#  '310': ['$#!radio', '$#!wave', '$#!mind', '$#!cancer'],
#  '311': ['$#!espionage'],
#  '312': ['$#!hydroponics'],
#  '313': ['$#!levitation', '$#!magnetic_levitation'],
#  '314': ['$#!marine', '$#!vegetation'],
#  '315': ['$#!highway', '$#!accident'],
#  '316': ['$#!polygamy', '$#!polyandry', '$#!polygyny'],
#  '317': ['$#!facsimile'],
#  '318': ['$#!best', '$#!retirement', '$#!state'],
#  '319': ['$#!fuel', '$#!source'],
#  '320': ['$#!fiber', '$#!eye', '$#!cable'],
#  '321': ['$#!womanhood', '$#!parliament'],
#  '322': ['$#!international', '$#!artwork', '$#!crime'],
#  '323': ['$#!plagiarism'],
#  '324': ['$#!argentine', '$#!sexual_intercourse'],
#  '325': ['$#!fad', '$#!life_style'],
#  '326': ['$#!ferry', '$#!sinking'],
#  '327': ['$#!slavery'],
#  '328': ['$#!pope', '$#!blessedness'],
#  '329': ['$#!mexican', '$#!tune', '$#!pollution'],
#  '330': ['$#!iran', '$#!iraq', '$#!cooperation'],
#  '331': ['$#!world', '$#!savings_bank', '$#!criticism'],
#  '332': ['$#!tax', '$#!evasion'],
#  '333': ['$#!antibiotic', '$#!bacteria', '$#!disease'],
#  '334': ['$#!export', '$#!control_condition', '$#!cryptography'],
#  '335': ['$#!parent'],
#  '336': ['$#!black', '$#!bear', '$#!attack'],
#  '337': ['$#!hepatitis'],
#  '338': ['$#!risk', '$#!aspirin'],
#  '339': ['$#!drug', '$#!treatment'],
#  '340': ['$#!state', '$#!mine', '$#!prohibition'],
#  '341': ['$#!airport', '$#!security_system'],
#  '342': ['$#!extrusion'],
#  '343': ['$#!police', '$#!end'],
#  '344': ['$#!abuse', '$#!vitamin_e', '$#!mail'],
#  '345': ['$#!tobacco', '$#!sale'],
#  '346': ['$#!standard'],
#  '347': ['$#!wildlife', '$#!extinction'],
#  '348': ['$#!agoraphobia'],
#  '349': ['$#!metamorphosis'],
#  '350': ['$#!health', '$#!computer', '$#!terminal'],
#  '351': ['$#!petroleum', '$#!exploration'],
#  '352': ['$#!chunnel', '$#!impact'],
#  '353': ['$#!antarctica', '$#!exploration'],
#  '354': ['$#!journalist', '$#!risk'],
#  '355': [],
#  '356': ['$#!estrogen', '$#!united_kingdom'],
#  '357': ['$#!water_system'],
#  '358': ['$#!rake', '$#!alcohol', '$#!fatality'],
#  '359': ['$#!store', '$#!predictor'],
#  '360': ['$#!drug', '$#!legalization', '$#!benefit'],
#  '361': ['$#!clothing', '$#!sweatshop'],
#  '362': [],
#  '363': ['$#!transportation_system', '$#!tunnel', '$#!catastrophe'],
#  '364': ['$#!rabies'],
#  '365': ['$#!elevation'],
#  '366': ['$#!nitrile', '$#!use'],
#  '367': ['$#!piracy'],
#  '368': ['$#!fertilization'],
#  '369': ['$#!anorexia', '$#!bulimia'],
#  '370': ['$#!food', '$#!drug', '$#!torah'],
#  '371': ['$#!health', '$#!policy'],
#  '372': ['$#!american', '$#!casino'],
#  '373': ['$#!encoding', '$#!equipment', '$#!export'],
#  '374': ['$#!nobel', '$#!trophy', '$#!winner'],
#  '375': ['$#!hydrogen', '$#!energy'],
#  '376': ['$#!worldly_concern', '$#!motor_hotel'],
#  '377': ['$#!cigar', '$#!smoke'],
#  '378': ['$#!resistance'],
#  '379': [],
#  '380': ['$#!fleshiness', '$#!treatment'],
#  '381': ['$#!medicine'],
#  '382': ['$#!hydrogen', '$#!fuel', '$#!car'],
#  '383': ['$#!illness', '$#!drug'],
#  '384': ['$#!space', '$#!station', '$#!moon'],
#  '385': ['$#!fuel', '$#!car'],
#  '386': ['$#!child'],
#  '387': ['$#!waste'],
#  '388': ['$#!territory', '$#!enhancement'],
#  '389': ['$#!technology', '$#!transfer'],
#  '390': ['$#!orphan', '$#!drug'],
#  '391': ['$#!gas_constant', '$#!vitamin_d', '$#!drug', '$#!price'],
#  '392': ['$#!robotics'],
#  '393': ['$#!mercy'],
#  '394': ['$#!home_plate', '$#!schooling'],
#  '395': ['$#!tourism'],
#  '396': ['$#!construction', '$#!syndrome'],
#  '397': ['$#!car', '$#!recall'],
#  '398': ['$#!europe'],
#  '399': ['$#!vessel'],
#  '400': ['$#!amazon', '$#!rain', '$#!forest'],
#  '401': ['$#!minority', '$#!germany'],
#  '402': ['$#!genetics'],
#  '403': ['$#!osteoporosis'],
#  '404': ['$#!ireland', '$#!peace', '$#!talk'],
#  '405': ['$#!event'],
#  '406': ['$#!parkinson', '$#!disease'],
#  '407': ['$#!wildlife', '$#!preserve'],
#  '408': ['$#!storm'],
#  '409': ['$#!pan'],
#  '410': ['$#!agreement'],
#  '411': ['$#!shipwreck', '$#!treasure'],
#  '412': ['$#!airport', '$#!security'],
#  '413': ['$#!sword', '$#!production'],
#  '414': ['$#!cuba', '$#!sugar', '$#!export'],
#  '415': ['$#!drug', '$#!triangulum'],
#  '416': ['$#!gorge', '$#!undertaking'],
#  '417': ['$#!creativity'],
#  '418': ['$#!quilt', '$#!income'],
#  '419': ['$#!car', '$#!tire'],
#  '420': ['$#!carbon_paper', '$#!monoxide', '$#!poisoning'],
#  '421': ['$#!waste', '$#!disposal'],
#  '422': ['$#!artwork'],
#  '423': [],
#  '424': ['$#!suicide'],
#  '425': ['$#!money'],
#  '426': ['$#!law', '$#!enforcement', '$#!pawl'],
#  '427': ['$#!ultraviolet', '$#!wrong', '$#!eye'],
#  '428': ['$#!birth', '$#!rates'],
#  '429': ['$#!legionnaire'],
#  '430': ['$#!killer', '$#!bee', '$#!attack'],
#  '431': ['$#!technology'],
#  '432': ['$#!motorist', '$#!police'],
#  '433': ['$#!philosophy', '$#!stoicism'],
#  '434': ['$#!estonia', '$#!economy'],
#  '435': ['$#!population', '$#!increase'],
#  '436': ['$#!railway', '$#!accident'],
#  '437': ['$#!deregulation', '$#!natural_gas', '$#!electric'],
#  '438': ['$#!tourism', '$#!increase'],
#  '439': ['$#!invention', '$#!discovery'],
#  '440': ['$#!child', '$#!parturiency'],
#  '441': ['$#!disease'],
#  '442': ['$#!heroic_verse', '$#!acts_of_the_apostles'],
#  '443': ['$#!uranium', '$#!second', '$#!investment', '$#!africa'],
#  '444': ['$#!fluid'],
#  '445': ['$#!womanhood'],
#  '446': ['$#!tourist', '$#!violence'],
#  '447': ['$#!locomotive'],
#  '448': ['$#!ship', '$#!personnel_casualty'],
#  '449': ['$#!antibiotic', '$#!ineffectiveness'],
#  '450': ['$#!hussein', '$#!peace'],
#  '601': ['$#!turkey', '$#!iraq', '$#!water_system'],
#  '602': ['$#!czechoslovakian', '$#!slovak', '$#!sovereignty'],
#  '603': ['$#!tobacco', '$#!cigarette', '$#!lawsuit'],
#  '604': ['$#!disease', '$#!arthritis'],
#  '605': ['$#!great', '$#!united_kingdom', '$#!health', '$#!care'],
#  '606': ['$#!stage', '$#!trap'],
#  '607': ['$#!code'],
#  '608': ['$#!security'],
#  '609': ['$#!caput', '$#!alcohol', '$#!pulmonary_tuberculosis'],
#  '610': ['$#!wage', '$#!impact'],
#  '611': ['$#!kurd', '$#!germany', '$#!violence'],
#  '612': ['$#!tibet', '$#!dissenter'],
#  '613': ['$#!berlin', '$#!wall', '$#!disposal'],
#  '614': ['$#!tomato'],
#  '615': ['$#!timbre', '$#!export'],
#  '616': ['$#!mexico'],
#  '617': ['$#!soviet_union', '$#!cuba', '$#!economy'],
#  '618': ['$#!ayatollah', '$#!khomeini', '$#!end'],
#  '619': ['$#!mandela', '$#!scandal'],
#  '620': ['$#!france', '$#!examination'],
#  '621': ['$#!womanhood', '$#!church_service', '$#!england'],
#  '622': ['$#!price', '$#!repair'],
#  '623': ['$#!chemical', '$#!weapon'],
#  '624': ['$#!star_topology', '$#!war'],
#  '625': ['$#!apprehension', '$#!world_trade_center'],
#  '626': ['$#!stampede'],
#  '627': ['$#!food', '$#!crisis'],
#  '628': ['$#!uranium', '$#!second', '$#!invasion', '$#!panama'],
#  '629': ['$#!miscarriage', '$#!attack'],
#  '630': ['$#!gulf', '$#!war', '$#!syndrome'],
#  '631': ['$#!mandela', '$#!south', '$#!africa', '$#!president'],
#  '632': ['$#!asia', '$#!tin', '$#!mining'],
#  '633': ['$#!welshman', '$#!devolution'],
#  '634': ['$#!liter', '$#!end'],
#  '635': ['$#!doctor_of_the_church', '$#!suicide'],
#  '636': ['$#!jury', '$#!duty', '$#!exemption'],
#  '637': ['$#!increase', '$#!hormone'],
#  '638': ['$#!conviction'],
#  '639': ['$#!consumer', '$#!wrinkle', '$#!shopping'],
#  '640': ['$#!pregnancy', '$#!policy'],
#  '641': ['$#!valdez', '$#!wildlife', '$#!marine', '$#!life_sentence'],
#  '642': ['$#!square', '$#!dissenter'],
#  '643': ['$#!decameter', '$#!pacific'],
#  '644': ['$#!animal', '$#!significance'],
#  '645': ['$#!software', '$#!piracy'],
#  '646': ['$#!food', '$#!stamp', '$#!increase'],
#  '647': ['$#!windmill', '$#!electricity'],
#  '648': ['$#!syndicate', '$#!law'],
#  '649': ['$#!computer', '$#!virus'],
#  '650': ['$#!tax', '$#!evasion'],
#  '651': ['$#!uranium', '$#!second', '$#!population'],
#  '652': [],
#  '653': ['$#!basque_homeland_and_freedom', '$#!basque', '$#!terrorism'],
#  '654': ['$#!sexual_activity', '$#!school'],
#  '655': ['$#!attention_deficit_disorder', '$#!diagnosis', '$#!treatment'],
#  '656': ['$#!star', '$#!poisoning', '$#!child'],
#  '657': ['$#!school', '$#!prayer'],
#  '658': ['$#!pregnancy'],
#  '659': ['$#!cruise', '$#!health', '$#!safety'],
#  '660': ['$#!california'],
#  '661': ['$#!melanoma', '$#!treatment', '$#!lawsuit'],
#  '662': ['$#!protective_covering'],
#  '663': ['$#!agent', '$#!orange', '$#!photograph'],
#  '664': ['$#!american', '$#!indian', '$#!museum'],
#  '665': ['$#!poverty', '$#!africa', '$#!sahara'],
#  '666': ['$#!thatcher', '$#!resignation', '$#!impact'],
#  '667': ['$#!spouse', '$#!family'],
#  '668': ['$#!poverty', '$#!disease'],
#  '669': ['$#!rotation'],
#  '670': ['$#!uranium', '$#!second', '$#!election'],
#  '671': ['$#!salvation', '$#!army', '$#!benefit'],
#  '672': ['$#!national_rifle_association', '$#!membership', '$#!visibility'],
#  '673': ['$#!withdrawal', '$#!afghanistan'],
#  '674': ['$#!greenpeace'],
#  '675': ['$#!olympic_games', '$#!swimming'],
#  '676': ['$#!polish'],
#  '677': ['$#!tugboat', '$#!pisa'],
#  '678': ['$#!hands', '$#!impact'],
#  '679': ['$#!adoption', '$#!record'],
#  '680': ['$#!immigrant', '$#!school'],
#  '681': ['$#!wind_instrument', '$#!world_power', '$#!placement'],
#  '682': ['$#!adult', '$#!immigrant'],
#  '683': ['$#!czechoslovakia', '$#!dissolution'],
#  '684': ['$#!part', '$#!time', '$#!benefit'],
#  '685': ['$#!academy_award', '$#!winner', '$#!survival'],
#  '686': ['$#!argentina', '$#!dollar'],
#  '687': ['$#!northern', '$#!ireland', '$#!industry'],
#  '688': ['$#!uranium', '$#!second', '$#!medium', '$#!diagonal'],
#  '689': ['$#!syndicate', '$#!planning', '$#!aid'],
#  '690': ['$#!college', '$#!education', '$#!advantage'],
#  '691': ['$#!film_editing', '$#!forest'],
#  '692': ['$#!prostate_gland',
#   '$#!cancer',
#   '$#!signal_detection',
#   '$#!treatment'],
#  '693': ['$#!newspaper', '$#!medium'],
#  '694': ['$#!compost', '$#!voltaic_pile'],
#  '695': ['$#!collar', '$#!crime', '$#!sentence'],
#  '696': ['$#!safety', '$#!credit_card', '$#!surgery'],
#  '697': ['$#!tune', '$#!traffic', '$#!restrainer'],
#  '698': ['$#!literacy', '$#!rates', '$#!africa'],
#  '699': ['$#!terminus', '$#!terminus_ad_quem'],
#  '700': ['$#!gasoline', '$#!tax', '$#!uranium', '$#!second']}

# %%
def load_doc(file_doc,all_docs={},all_concept={},pre_process=True):
        """
            Fonction qui load un fichier file_doc. 
            pre_process -> Bool qui dit si on effectue le preprocessing ou non. 
        """
        
        with codecs.open(file_doc,'r',encoding='utf-8',errors='ignore') as f_:
            soup = BeautifulSoup(f_.read(),"html.parser")
        docs = soup.find_all('doc')
        for d_ in docs :
            text = np.array(d_.text.split()[1:])
            doc_id = d_.docno.text.strip()
            all_docs[doc_id] = list(text)
            index = np.where(np.char.find(text, '$#')>=0)
            all_concept[doc_id] = list(text[index])
        return all_docs,all_concept

# %%
a_doc,a_concept=load_doc('/local/karmim/Stage_M1_RI/data/annotated_collection_tagme_score/015/FR94/10/FR941003.2')

# %%
a_concept['FR941003-2-00002']
# Out:
# ['$#!Dwelling',
#  '$#!Guarantee',
#  '$#!Education',
#  '$#!Investment',
#  '$#!Equal_opportunity',
#  '$#!United_States_Agency_for_International_Development',
#  '$#!Guarantee',
#  '$#!Loan',
#  '$#!Indonesia',
#  '$#!Education',
#  '$#!Loan',
#  '$#!Deed',
#  '$#!Infrastructure',
#  '$#!Welfare',
#  '$#!Indonesia',
#  '$#!Indonesia',
#  '$#!Loan',
#  '$#!Loan',
#  '$#!Debtor',
#  '$#!Loan',
#  '$#!Indonesia',
#  '$#!Guarantee',
#  '$#!Attention_deficit_hyperactivity_disorder',
#  '$#!Budget',
#  '$#!Timor',
#  '$#!Jakarta',
#  '$#!Indonesia',
#  '$#!Communication',
#  '$#!Telephone',
#  '$#!Jakarta',
#  '$#!Indonesia',
#  '$#!Telephone',
#  '$#!Fax',
#  '$#!Telephone',
#  '$#!Creditor',
#  '$#!Debtor',
#  '$#!Interest',
#  '$#!Finance',
#  '$#!Dwelling',
#  '$#!Guarantee',
#  '$#!Jakarta',
#  '$#!United_States_Agency_for_International_Development',
#  '$#!Medan',
#  '$#!Jakarta',
#  '$#!Indonesia',
#  '$#!Fax',
#  '$#!Telecommunication',
#  '$#!Telephone',
#  '$#!Natural_environment',
#  '$#!Telecommunication',
#  '$#!Telephone',
#  '$#!Interest',
#  '$#!Loan',
#  '$#!Interest_rate',
#  '$#!Rate_(mathematics)',
#  '$#!Prepayment_of_loan',
#  '$#!Option_(finance)',
#  '$#!Statute',
#  '$#!Military_reserve_force',
#  '$#!Federal_Deposit_Insurance_Corporation',
#  '$#!United_States_Agency_for_International_Development',
#  '$#!Loan',
#  '$#!Fee',
#  '$#!Fee',
#  '$#!Expense',
#  '$#!Loan',
#  '$#!Closing_(real_estate)']

# %%
def load_all_doc(all_file,doc_json="/local/karmim/Stage_M1_RI/data/object_python/concept_part/anotated_doc.json",concept_doc_json="/local/karmim/Stage_M1_RI/data/object_python/concept_part/all_concept_doc.json"):
    
    exists1 = os.path.isfile(doc_json)
    exists2 = os.path.isfile(concept_doc_json)
    all_doc = {}
    all_concept={}
    if not exists1 or not exists2:
        
        for f in all_file:

            print("f -> ",f)
            load_doc(f,all_doc,all_concept)

        save = json.dumps(all_doc)
        f = open(doc_json,"w")
        f.write(save)
        f.close()
        print("document annoté sauvegardé...")
        save = json.dumps(concept_doc_json)
        f = open(doc_json,"w")
        f.write(save)
        f.close()
        print(" concept des documents sauvegardé...")
    else:
        
        print("Chargement du fichier json : anotated_doc.json ...")
        with open(doc_json) as json_file:
            all_doc = json.load(json_file)
        print("Chargement du fichier json : all_concept_doc.json ...")
        with open(concept_doc_json) as json_file:
            all_concept = json.load(json_file)

    #
    return all_doc,all_concept

def pre_process_doc(all_document={},all_concept={},CUSTOM_FILTERS=[lambda x: x.lower(),remove_stopwords],json_doc_preprocess="/local/karmim/Stage_M1_RI/data/object_python/concept_part/preprocess_doc.json",json_concept_preprocess="/local/karmim/Stage_M1_RI/data/object_python/concept_part/preprocess_concept.json"):
    exists1 = os.path.isfile(json_doc_preprocess)
    exists2 = os.path.isfile(json_concept_preprocess)
    if not exists1 or not exists2:
        for k in all_document : 
            all_document[k] = preprocess_string(' '.join(all_document[k]),CUSTOM_FILTERS)
            all_concept[k] = preprocess_string(' '.join(all_concept[k]),[lambda x : x.lower()]) # We only need to low the concept
        
        save = json.dumps(all_document)
        f = open(json_doc_preprocess,"w")
        f.write(save)
        f.close()
        print("document annoté preprocessé sauvegardé...")
        save = json.dumps(all_concept)
        f = open(json_concept_preprocess,"w")
        f.write(save)
        f.close()
        print("concept des documents preprocessé sauvegardé...")
    
    else:     
        print("Chargement du fichier json : preprocess_doc.json ...")
        with open(json_doc_preprocess) as json_file:
            all_document = json.load(json_file)
        print("Chargement du fichier json : preprocess_concept.json ...")
        with open(json_concept_preprocess) as json_file:
            all_concept = json.load(json_file)
        
        
    return all_document,all_concept
CUSTOM_FILTERS = [lambda x: x.lower(),remove_stopwords]   
#ad,ac = pre_process_doc()

# %%
#ad,ac = load_all_doc(all_file_name)
#ad,ac = pre_process_doc(ad,ac)
# Out:
# Chargement du fichier json : anotated_doc.json ...
# Chargement du fichier json : all_concept_doc.json ...
# Chargement du fichier json : preprocess_doc.json ...
# Chargement du fichier json : preprocess_concept.json ...

# %%
ad,ac = pre_process_doc() # Execute load_all_doc() first if the files json are not saved. cellul before

# %%
ad['LA052889-0021']
# Out:
# ['new',
#  'jazz',
#  '$#!jazz',
#  'oriented',
#  'vocal',
#  'groups',
#  'rare',
#  'ensemble',
#  'members',
#  'studied',
#  'ithaca',
#  'college',
#  'welcomed',
#  'step',
#  'right',
#  'direction',
#  'darmon',
#  'meader',
#  'key',
#  'figure',
#  'singer',
#  '$#!singing',
#  'composer',
#  '$#!composer',
#  'arranger',
#  '$#!arrangement',
#  'tenor',
#  'saxophonist',
#  'peter',
#  'eldridge',
#  'kim',
#  'nazarian',
#  'sara',
#  'krieger',
#  'caprice',
#  'fox',
#  'writers',
#  'contributing',
#  'lyrics',
#  '$#!lyrics',
#  'music',
#  '$#!music',
#  'originals',
#  'halfway',
#  'profound',
#  'trivial',
#  'way',
#  'blend',
#  'splendid',
#  'instrumental',
#  'backing',
#  '$#!backing_vocalist',
#  'synthesizer',
#  '$#!synthesizer',
#  'sequencer',
#  '$#!music_sequencer',
#  'programming',
#  '$#!programming_(music)',
#  'aggressive',
#  'times',
#  'group',
#  'little',
#  'anxious',
#  'commercial',
#  'success',
#  'caravan',
#  '$#!caravan_(1936_song)',
#  'interludes',
#  '$#!break_(music)',
#  'scatting',
#  'polysyllabic',
#  'vocalese',
#  'inclusion',
#  'printed',
#  'lyrics',
#  'invaluable',
#  'originals',
#  'national',
#  'amnesia',
#  '$#!amnesia',
#  'aims',
#  'social',
#  'significance',
#  'dare',
#  'moon',
#  '$#!moon_(film)',
#  'cheerful',
#  'wish',
#  'star',
#  'ditties',
#  'wordless',
#  'baroque',
#  '$#!baroque_music',
#  'samba',
#  '$#!samba',
#  'choral',
#  'introduction',
#  'charming',
#  'street',
#  'party',
#  'melody',
#  'unpartylike',
#  'words',
#  'program',
#  'closes',
#  'brief',
#  'slow',
#  'pensive',
#  'come',
#  'home',
#  'outstanding',
#  'solo',
#  '$#!album',
#  'jazz',
#  '$#!jazz',
#  'vocalists',
#  '$#!singing',
#  'new',
#  'york',
#  'voices',
#  '$#!voice_acting',
#  'fox',
#  '$#!fox_broadcasting_company',
#  'krieger',
#  'come',
#  'closest',
#  'event',
#  'promising',
#  'debut',
#  'sphinx',
#  '$#!sphinx',
#  'allegro',
#  'jazz',
#  '$#!jazz',
#  'ensemble',
#  'mobile',
#  'fidelity',
#  'mfco',
#  'jazz',
#  '$#!jazz',
#  'critics',
#  'soviet',
#  'union',
#  'voted',
#  'foremost',
#  'jazz',
#  '$#!jazz',
#  'group',
#  'clearly',
#  'soviets',
#  'fusion',
#  'seriously',
#  'hour',
#  'plus',
#  'contemporary',
#  'music',
#  'suites',
#  'world',
#  'parts',
#  'movement',
#  'legend',
#  'followed',
#  'hard',
#  'boppish',
#  'title',
#  'number',
#  'extended',
#  'portrait',
#  'composed',
#  'keyboard',
#  '$#!keyboard_instrument',
#  'soloist',
#  'nikolai',
#  'levinovsky',
#  'conception',
#  'performance',
#  '$#!performance',
#  'recording',
#  'exemplary',
#  'right',
#  'balance',
#  'fusion',
#  '$#!jazz_fusion',
#  'jazz',
#  '$#!jazz',
#  'elements',
#  'touches',
#  'humor',
#  '$#!humorism',
#  'high',
#  'octane',
#  '$#!octane',
#  'cooking',
#  'igor',
#  'butman',
#  'group',
#  '$#!musical_ensemble',
#  'tenor',
#  'saxophonist',
#  'moved',
#  'united',
#  'states',
#  'recorded',
#  'grover',
#  'washington',
#  'use',
#  'synthesizers',
#  '$#!synthesizer',
#  'effective',
#  'bassist',
#  'viktor',
#  'dvoskin',
#  'outstanding',
#  'allegro',
#  '$#!tempo',
#  'trigger',
#  'situation',
#  'american',
#  'musicians',
#  'copying',
#  'soviet',
#  'counterparts',
#  'ellington',
#  'masterpieces',
#  'american',
#  'jazz',
#  '$#!jazz',
#  'orchestra',
#  '$#!orchestra',
#  'conducted',
#  'john',
#  'lewis',
#  'east',
#  'west',
#  'duke',
#  'memorex',
#  'old',
#  'ethical',
#  'question',
#  'resurfaces',
#  'repertory',
#  'ensemble',
#  'interprets',
#  'works',
#  'ellington',
#  'golden',
#  'age',
#  'instead',
#  'duke',
#  'piano',
#  '$#!piano',
#  'dick',
#  'katz',
#  'copying',
#  'solo',
#  'note',
#  '$#!musical_note',
#  'note',
#  'original',
#  'record',
#  '$#!sound_recording_and_reproduction',
#  'trumpet',
#  '$#!trumpet',
#  'john',
#  'eckert',
#  'copying',
#  'solo',
#  '$#!solo_(music)',
#  'cootie',
#  'williams',
#  'williams',
#  'inherited',
#  'ray',
#  'nance',
#  'loren',
#  'schoenberg',
#  'better',
#  'known',
#  'lester',
#  'young',
#  'disciple',
#  'suggests',
#  'ben',
#  'webster',
#  'forth',
#  'statement',
#  'notes',
#  'duke',
#  'music',
#  'score',
#  '$#!sheet_music',
#  'false',
#  'band',
#  'music',
#  '$#!music',
#  'hearts',
#  'fingers',
#  'creative',
#  'minds',
#  '$#!movement_for_the_intellectually_disabled_of_singapore',
#  'johnny',
#  'hodges',
#  'giants',
#  '$#!giants_(dizzy_gillespie_album)',
#  'integral',
#  'duke',
#  'triumphs',
#  'solos',
#  'replaced',
#  'familiar',
#  'originals',
#  'advised',
#  'masterful',
#  'creations',
#  'ko',
#  'ko',
#  'main',
#  'stem',
#  'jack',
#  'bear',
#  'sounded',
#  'better',
#  'conga',
#  '$#!conga',
#  'brava',
#  'cotton',
#  'tail',
#  'schoenberg',
#  '$#!arnold_schoenberg',
#  'ad',
#  'libbing',
#  'lewis',
#  'guidance',
#  'charts',
#  'copied',
#  'old',
#  'records',
#  'duke',
#  'left',
#  'complete',
#  'written',
#  'scores',
#  '$#!sheet_music',
#  'sound',
#  'magnificent',
#  'heretical',
#  '$#!heresy',
#  'believe',
#  'version',
#  'bojangles',
#  'greater',
#  'original',
#  'lewis',
#  'replaces',
#  'katz',
#  'piano',
#  '$#!piano',
#  'play',
#  'choruses',
#  'rockin',
#  'rhythm',
#  'style',
#  'finest',
#  'hour',
#  'boils',
#  'versions',
#  'prefer',
#  'derivative',
#  'ones',
#  'digital',
#  'sound',
#  'originals',
#  'mono',
#  'insisting',
#  'creative',
#  'credit',
#  'ellington',
#  'possible',
#  'half',
#  'dozen',
#  'benny',
#  'goodman',
#  'yale',
#  'archives',
#  'vol',
#  'music',
#  'masters',
#  'cij',
#  'released',
#  'tracks',
#  'stem',
#  'week',
#  'goodman',
#  'spent',
#  'brussels',
#  '$#!brussels',
#  'group',
#  'included',
#  'zoot',
#  'sims',
#  'prominent',
#  'big',
#  'band',
#  'small',
#  'group',
#  'numbers',
#  'trumpeter',
#  'taft',
#  'jordan',
#  'vocals',
#  '$#!singing',
#  'jimmy',
#  'rushing',
#  'elegant',
#  'sadly',
#  'neglected',
#  'ethel',
#  'ennis',
#  'hoarse',
#  'goofing',
#  'lyrics',
#  'rushing',
#  'indomitable',
#  'self',
#  'fine',
#  'romance',
#  'duet',
#  'ennis',
#  'goodman',
#  'clarinet',
#  '$#!clarinet',
#  'moments',
#  'awkward',
#  'times',
#  'fluffs',
#  'makes',
#  'intriguing',
#  'set',
#  'old',
#  'familiar',
#  'items',
#  'little',
#  'known',
#  'charts',
#  'bobby',
#  'gutesha',
#  'sid',
#  'feller',
#  'gil',
#  'evans',
#  'gula',
#  'matari',
#  'quincy',
#  'jones',
#  'cd',
#  'cuts',
#  'minutes',
#  'loaded',
#  'special',
#  'effects',
#  'female',
#  'vocal',
#  'group',
#  'group',
#  'quartet',
#  '$#!string_quartet',
#  'celli',
#  '$#!cello',
#  'bass',
#  '$#!double_bass',
#  'marimba',
#  '$#!marimba',
#  'guitarist',
#  '$#!electric_guitar',
#  'whistles',
#  'works',
#  'toots',
#  'thielemans',
#  'bassist',
#  'sings',
#  'plays',
#  'major',
#  'holley',
#  'title',
#  'tune',
#  'somberly',
#  'dramatic',
#  'bridge',
#  'troubled',
#  'water',
#  'soul',
#  'vocal',
#  'waltz',
#  '$#!waltz',
#  'miles',
#  'davis',
#  'blues',
#  '$#!blues',
#  'walkin',
#  'nat',
#  'adderley',
#  'hummin',
#  'touch',
#  'old',
#  'big',
#  'band',
#  'sound',
#  'moments',
#  'milt',
#  'jackson',
#  'hubert',
#  'laws',
#  'sonny',
#  'ken',
#  'peplowski',
#  'quintet',
#  'concord',
#  'jazz',
#  'ccd',
#  '$#!charge-coupled_device',
#  'peplowski',
#  'rare',
#  'younger',
#  'men',
#  'lean',
#  'jazz',
#  'traditions',
#  'highly',
#  'promising',
#  'clarinetist',
#  'warm',
#  'websterish',
#  'tenor',
#  '$#!tenor',
#  'soloist',
#  '$#!solo_(music)',
#  'plays',
#  'agreeable',
#  'alto',
#  'backed',
#  'conservative',
#  'rhythm',
#  'section',
#  'wakes',
#  'half',
#  'nelson',
#  'latinized',
#  'treatment',
#  'good',
#  'solo',
#  'work',
#  'pianist',
#  '$#!pianist',
#  'dave',
#  'frishberg']

# %%
ac['LA052889-0051']
# Out:
# ['$#!spear',
#  '$#!elder_(administrative_title)',
#  '$#!war',
#  '$#!risk',
#  '$#!rite_of_passage',
#  '$#!tribe',
#  '$#!hospitality_industry',
#  '$#!today_(u.s._tv_program)',
#  '$#!people_(magazine)',
#  '$#!calypso_(comics)',
#  '$#!seattle',
#  '$#!aircraft',
#  '$#!ship',
#  '$#!mediterranean_sea',
#  '$#!seattle',
#  '$#!ship',
#  '$#!australia',
#  '$#!military_base',
#  '$#!rabaul',
#  '$#!rabaul',
#  '$#!airplane',
#  '$#!planing_(boat)',
#  '$#!crew',
#  '$#!shipwreck',
#  '$#!sea',
#  '$#!underwater_diving',
#  '$#!airplane',
#  '$#!metre',
#  '$#!calypso_music',
#  '$#!decompression_(diving)',
#  '$#!decade',
#  '$#!history',
#  '$#!airplane',
#  '$#!fuselage',
#  '$#!skeleton',
#  '$#!shrine',
#  '$#!propeller',
#  '$#!spirit',
#  '$#!vegetation',
#  '$#!ocean_current',
#  '$#!réunion',
#  '$#!beauty',
#  '$#!war',
#  '$#!peace']

# %% [markdown]
# ## Pre-processing

# %%
def count_concept(ac):
    all_concept = []
    for k in ac: 
        for w in ac[k]:
            all_concept.append(w)

    unique, counts = np.unique(all_concept, return_counts=True)
    dico_concept = dict(zip(unique, counts))
    return np.array(all_concept),dico_concept
all_c,dico_concept = count_concept(ac)
print("There is",len(all_c),"concepts in the collection Robust4.")
# Out:
# There is 17008375 concepts in the collection Robust4.

# %%
print("There is",len(dico_concept),"unique concepts in the collection Robust4")
# Out:
# There is 242663 unique concepts in the collection Robust4

# %%
dico_concept
# Out:
# {'$#!"heroes"_(david_bowie_album)': 4,
#  '$#!"heroes"_(david_bowie_song)': 47,
#  '$#!"mad"_mike_whiddett': 1,
#  '$#!"v"_device': 4,
#  '$#!"weird_al"_yankovic': 10,
#  '$#!"wild_bill"_hickok': 4,
#  '$#!$_(film)': 3,
#  '$#!&tv': 2,
#  "$#!'abd_allah_ibn_rawahah": 2,
#  "$#!'amr_ibn_al-'as": 203,
#  "$#!'amran": 2,
#  "$#!'amran_governorate": 2,
#  "$#!'aoa": 5,
#  "$#!'aparima": 1,
#  "$#!'aql": 16,
#  "$#!'asir_region": 13,
#  "$#!'atika_wahbi_al-khazraji": 2,
#  "$#!'ndrangheta": 47,
#  "$#!'ote'a": 13,
#  "$#!'s-hertogenbosch": 2,
#  "$#!'umayri": 1,
#  '$#!(do_the)_mashed_potatoes': 3,
#  '$#!(e,e)-2,4-decadienal': 1,
#  '$#!(hydroxyethyl)methacrylate': 1,
#  "$#!(i_can't_get_no)_satisfaction": 79,
#  '$#!(keep_feeling)_fascination': 1,
#  '$#!(methyl-co(iii)_methylamine-specific_corrinoid_protein):coenzyme_m_methyltransferase': 1,
#  '$#!(you_drive_me)_crazy': 2,
#  '$#!(z)-4-amino-2-butenoic_acid': 1,
#  '$#!(ε,_δ)-definition_of_limit': 19,
#  "$#!+'justments": 1,
#  '$#!-elect': 3,
#  '$#!-ene': 1,
#  '$#!-gram': 2,
#  '$#!-gry': 1,
#  '$#!-ism': 9,
#  '$#!-land': 1,
#  '$#!-logy': 22,
#  '$#!-nomics': 4,
#  '$#!-ol': 1,
#  '$#!-stan': 3,
#  '$#!-wich_town': 3,
#  '$#!....and_proud': 78,
#  '$#!...and_then_there_were_three...': 2,
#  '$#!...cooks!': 1,
#  '$#!...for_the_kids_(gym_class_heroes_album)': 1,
#  '$#!...in_translation': 52,
#  '$#!...phobia': 1,
#  '$#!.357_magnum': 6,
#  '$#!.44_magnum': 21,
#  '$#!.ac': 1,
#  '$#!.ad': 2,
#  '$#!.af': 3,
#  '$#!.ag': 1,
#  '$#!.ai': 1,
#  '$#!.al': 112,
#  '$#!.ao': 2,
#  '$#!.aq': 3,
#  '$#!.ar': 2,
#  '$#!.arpa': 1,
#  '$#!.ax': 2,
#  '$#!.az': 2,
#  '$#!.bb': 13,
#  '$#!.bd': 8,
#  '$#!.bf': 2,
#  '$#!.bg': 1,
#  '$#!.bh': 13,
#  '$#!.biz': 2,
#  '$#!.bj': 4,
#  '$#!.bn': 66,
#  '$#!.bo': 1,
#  '$#!.br': 1,
#  '$#!.bt': 21,
#  '$#!.bv': 2,
#  '$#!.bw': 3,
#  '$#!.bz': 2,
#  '$#!.cc': 2,
#  '$#!.cda_file': 2,
#  '$#!.cf': 3,
#  '$#!.ch': 2,
#  '$#!.ck': 1,
#  '$#!.cm': 6,
#  '$#!.co': 13,
#  '$#!.com': 11,
#  '$#!.cso': 16,
#  '$#!.cu': 1,
#  '$#!.cv': 8,
#  '$#!.dd': 4,
#  '$#!.dk': 2,
#  '$#!.dm': 22,
#  '$#!.dwg': 2,
#  '$#!.dz': 1,
#  '$#!.ec': 7,
#  '$#!.eh': 4,
#  '$#!.es': 8,
#  '$#!.et': 3,
#  '$#!.eu': 17,
#  '$#!.example': 14,
#  '$#!.exe': 23,
#  '$#!.fk': 5,
#  '$#!.fr': 4,
#  '$#!.frl': 13,
#  '$#!.gal': 1,
#  '$#!.gd': 2,
#  '$#!.ge': 3,
#  '$#!.gf': 1,
#  '$#!.gg': 10,
#  '$#!.gl': 5,
#  '$#!.gm': 1,
#  '$#!.gn': 1,
#  '$#!.gov': 14,
#  '$#!.gp': 1,
#  '$#!.gt': 3,
#  '$#!.gu': 3,
#  '$#!.gy': 1,
#  '$#!.hack': 15,
#  '$#!.hack_(video_game_series)': 1,
#  '$#!.hn': 1,
#  '$#!.ht': 6,
#  '$#!.hu': 5,
#  '$#!.id': 3,
#  '$#!.il': 1,
#  '$#!.im': 26,
#  '$#!.info': 2,
#  '$#!.info_(magazine)': 1,
#  '$#!.int': 4,
#  '$#!.iq': 2,
#  '$#!.je': 12,
#  '$#!.jobs': 6,
#  '$#!.jp': 1,
#  '$#!.ke': 3,
#  '$#!.kh': 5,
#  '$#!.kp': 7,
#  '$#!.kw': 3,
#  '$#!.la': 1,
#  '$#!.lc': 1,
#  '$#!.li': 16,
#  '$#!.ls': 5,
#  '$#!.lu': 23,
#  '$#!.lv': 1,
#  '$#!.ly': 1,
#  '$#!.m2ts': 2,
#  '$#!.mail': 1,
#  '$#!.mg': 9,
#  '$#!.mk': 1,
#  '$#!.ml': 1,
#  '$#!.mm': 3,
#  '$#!.mn': 35,
#  '$#!.mo': 2,
#  '$#!.mr': 95,
#  '$#!.ms': 5,
#  '$#!.mt': 5,
#  '$#!.mu': 3,
#  '$#!.na': 2,
#  '$#!.name': 1,
#  '$#!.ne': 1,
#  '$#!.net': 1,
#  '$#!.net_framework': 47,
#  '$#!.nf': 4,
#  '$#!.nfo': 11,
#  '$#!.ng': 1,
#  '$#!.ni': 1,
#  '$#!.om': 187,
#  '$#!.onion': 4,
#  '$#!.org': 1,
#  '$#!.pa': 2,
#  '$#!.pf': 41,
#  '$#!.ph': 5,
#  '$#!.pk': 2,
#  '$#!.pl': 4,
#  '$#!.pm': 1,
#  '$#!.post': 2,
#  '$#!.pr': 8,
#  '$#!.properties': 1,
#  '$#!.ps': 3,
#  '$#!.pw': 1,
#  '$#!.py': 20,
#  '$#!.qa': 5,
#  '$#!.re': 2,
#  '$#!.rs': 4,
#  '$#!.ru': 1,
#  '$#!.rw': 1,
#  '$#!.sa': 4,
#  '$#!.sb': 1,
#  '$#!.sd': 6,
#  '$#!.se': 15,
#  '$#!.shop': 1,
#  '$#!.sj': 2,
#  '$#!.sk': 5,
#  '$#!.sn': 1,
#  '$#!.sr': 4,
#  '$#!.st': 55,
#  '$#!.su': 3,
#  '$#!.sx': 1,
#  '$#!.sys': 5,
#  '$#!.tel': 8,
#  '$#!.tf': 1,
#  '$#!.tg': 2,
#  '$#!.th': 15,
#  '$#!.tj': 1,
#  '$#!.tk': 3,
#  '$#!.tl': 3,
#  '$#!.tp': 2,
#  '$#!.tr': 4,
#  '$#!.travel': 1,
#  '$#!.tt': 1,
#  '$#!.tv': 4,
#  '$#!.tv_(tv_channel)': 7,
#  '$#!.tw': 2,
#  '$#!.tz': 2,
#  '$#!.ug': 1,
#  '$#!.va': 4,
#  '$#!.ve': 30,
#  '$#!.vi': 3,
#  '$#!.vn': 7,
#  '$#!.vu': 1,
#  '$#!.wf': 1,
#  '$#!.ws': 1,
#  '$#!.xxx': 1,
#  '$#!.ye': 3,
#  '$#!.yu': 11,
#  '$#!/boot/': 1,
#  '$#!/film': 463,
#  '$#!0-10-0': 1,
#  '$#!0_(number)': 189,
#  '$#!1,000,000,000': 14030,
#  '$#!1,1,1,2-tetrafluoroethane': 29,
#  '$#!1,1,1-trichloroethane': 70,
#  '$#!1,1,2-trichloroethane': 5,
#  '$#!1,1-dichloro-1-fluoroethane': 6,
#  '$#!1,1-difluoroethane': 23,
#  '$#!1,2,3-trichloropropane': 21,
#  '$#!1,2,4-trimethylbenzene': 2,
#  '$#!1,2-dibromo-3-chloropropane': 17,
#  '$#!1,2-dibromoethane': 9,
#  '$#!1,2-dichloroethane': 15,
#  '$#!1,2-dichlorotetrafluoroethane': 9,
#  '$#!1,2-dimethylcyclopropane': 2,
#  '$#!1,3-benzodioxole': 5,
#  '$#!1,3-butadiene': 105,
#  '$#!1,3-dichloropropene': 7,
#  '$#!1,3-indandione': 1,
#  '$#!1,4-benzoquinone': 2,
#  '$#!1,4-butynediol': 4,
#  '$#!1,4-dichlorobenzene': 4,
#  '$#!1,4-dihydroxyanthraquinone': 2,
#  '$#!1,4-dioxane': 27,
#  '$#!1,4-dioxin': 4,
#  '$#!1,5-pentanediol': 3,
#  '$#!1,6-hexanediol': 2,
#  '$#!1-amino-2-propanol': 3,
#  '$#!1-chloro-1,1-difluoroethane': 5,
#  '$#!1-chloro-1,2,2,2-tetrafluoroethane': 1,
#  '$#!1-decanol': 50,
#  '$#!1-dodecene': 1,
#  '$#!1-methylnaphthalene': 1,
#  '$#!1-nitropyrene': 6,
#  '$#!1-octanol': 35,
#  '$#!1-propanol': 19,
#  '$#!1._fc_kaiserslautern': 1,
#  '$#!1._fc_magdeburg': 4,
#  '$#!1._fc_nürnberg': 1,
#  '$#!1._ffc_frankfurt': 15,
#  '$#!1._fsv_mainz_05': 8,
#  '$#!10,000_maniacs': 10,
#  '$#!1000_forms_of_fear': 2,
#  '$#!1000_ways_to_die': 1,
#  '$#!100_(number)': 16,
#  '$#!100_metres': 2,
#  '$#!101_dalmatians:_the_series': 4,
#  '$#!102_dalmatians': 1,
#  '$#!10_(number)': 16,
#  '$#!10_august_(french_revolution)': 1,
#  '$#!10th_lok_sabha': 4,
#  '$#!10th_united_states_congress': 3,
#  '$#!110_metres_hurdles': 24,
#  '$#!11_(number)': 15,
#  '$#!11th_united_states_congress': 5,
#  '$#!12-hour_clock': 278,
#  '$#!12-o-tetradecanoylphorbol-13-acetate': 9,
#  '$#!1231_property': 1,
#  '$#!123_mortlake_high_street': 3,
#  '$#!127th_wing': 1,
#  '$#!12_(number)': 26,
#  '$#!12_basic_principles_of_animation': 3,
#  '$#!12th_man_(football)': 145,
#  '$#!12th_united_states_congress': 1,
#  '$#!13_(number)': 5,
#  '$#!13th_united_states_congress': 1,
#  '$#!14_(number)': 2,
#  '$#!14_regions_of_augustan_rome': 2,
#  '$#!15&': 9,
#  '$#!1505_koranna': 1,
#  '$#!15_(number)': 1,
#  '$#!1600–50_in_western_european_fashion': 1,
#  '$#!16_(number)': 3,
#  '$#!16th_street_baptist_church_bombing': 28,
#  '$#!16th_united_states_congress': 4,
#  '$#!175r': 8,
#  '$#!17_(number)': 2,
#  '$#!17th-century_french_literature': 1,
#  '$#!1811–12_new_madrid_earthquakes': 5,
#  '$#!1820_settlers': 9,
#  '$#!1860_mount_lebanon_civil_war': 29,
#  '$#!1860_republican_national_convention': 7,
#  '$#!1865_in_new_zealand': 2,
#  '$#!1876_scotland_v_wales_football_match': 8,
#  "$#!1885–86_st._mary's_y.m.a._season": 1,
#  '$#!1890_british_ultimatum': 6,
#  '$#!1890_manifesto': 9,
#  '$#!18_(number)': 3,
#  '$#!18_july_2012_damascus_bombing': 3,
#  '$#!18th_united_states_congress': 3,
#  '$#!19-inch_rack': 17,
#  '$#!1903_clemson_tigers_football_team': 1,
#  '$#!1906_san_francisco_earthquake': 274,
#  '$#!1910_vanderbilt_vs._yale_football_game': 1,
#  '$#!1918_flu_pandemic': 26,
#  '$#!1920_nebi_musa_riots': 8,
#  '$#!1920s': 13,
#  '$#!1929_hebron_massacre': 710,
#  '$#!1930s': 23,
#  '$#!1932_ford': 1,
#  '$#!1932_summer_olympics': 7,
#  '$#!1934_fifa_world_cup_squads': 1,
#  '$#!1935_smu_mustangs_football_team': 1,
#  '$#!1939_german_ultimatum_to_lithuania': 12,
#  '$#!1940s': 21,
#  '$#!1945_chicago_cubs_season': 1,
#  '$#!1948_palestinian_exodus': 5,
#  '$#!1949_superga_fiat_g.212_crash': 1,
#  '$#!1950s': 36,
#  '$#!1950s_in_music': 4,
#  '$#!1951_nfl_championship_game': 19,
#  "$#!1953_iranian_coup_d'état": 48,
#  "$#!1954_guatemalan_coup_d'état": 534,
#  '$#!1954_transfer_of_crimea': 29,
#  '$#!1955_le_mans_disaster': 24,
#  '$#!1957_brooklyn_dodgers_season': 5,
#  '$#!1958_lebanon_crisis': 1,
#  '$#!1959_okinawa_f-100_crash': 3,
#  '$#!1960_democratic_national_convention': 23,
#  '$#!1960_u-2_incident': 251,
#  '$#!1960s': 61,
#  '$#!1960s_in_jazz': 3,
#  '$#!1960s_in_music': 3,
#  '$#!1961_green_bay_packers_season': 3,
#  '$#!1961_new_york_yankees_season': 50,
#  '$#!1962_new_york_mets_season': 4,
#  '$#!1962_united_states_tri-service_aircraft_designation_system': 15,
#  '$#!1963_south_vietnamese_coup': 4,
#  '$#!1964_philadelphia_phillies_season': 1,
#  '$#!1964_prl_symmetry_breaking_papers': 1,
#  '$#!1964_st._louis_cardinals_season': 3,
#  '$#!1966_fifa_world_cup': 2,
#  '$#!1966_nfl_season': 1,
#  '$#!1966_palomares_b-52_crash': 1,
#  '$#!1967_green_bay_packers_season': 7,
#  '$#!1967_nfl_championship_game': 21,
#  '$#!1967_nhl_expansion': 17,
#  '$#!1968_democratic_national_convention_protest_activity': 8,
#  '$#!1969_baltimore_orioles_season': 5,
#  '$#!1969_major_league_baseball_expansion': 7,
#  '$#!1969_new_york_mets_season': 5,
#  '$#!1969–70_new_york_knicks_season': 5,
#  '$#!1970_bhola_cyclone': 6,
#  '$#!1970_fifa_world_cup_qualification': 1,
#  '$#!1970s': 70,
#  '$#!1970s_in_western_fashion': 1,
#  '$#!1971_bangladesh_genocide': 74,
#  '$#!1971_jvp_insurrection': 4,
#  '$#!1971_san_fernando_earthquake': 155,
#  '$#!1971_turkish_military_memorandum': 159,
#  '$#!1972_israeli_air_raid_in_syria_and_lebanon': 15,
#  '$#!1972_nixon_visit_to_china': 3000,
#  '$#!1972_pittsburgh_steelers_season': 4,
#  "$#!1973_chilean_coup_d'état": 133,
#  '$#!1973_miami_dolphins_season': 1,
#  '$#!1973_oil_crisis': 672,
#  '$#!1973–75_recession': 116,
#  '$#!1975_australian_constitutional_crisis': 20,
#  '$#!1976_tangshan_earthquake': 1,
#  '$#!1976–77_uefa_cup': 1,
#  '$#!1977_dallas_cowboys_season': 1,
#  '$#!1978_los_angeles_dodgers_season': 1,
#  '$#!1978_pittsburgh_steelers_season': 1,
#  '$#!1978_south_lebanon_conflict': 1,
#  '$#!1979_boeing_707-323c_disappearance': 1,
#  '$#!1980_eruption_of_mount_st._helens': 10,
#  '$#!1980_oakland_raiders_season': 1,
#  '$#!1980_summer_olympics': 2,
#  '$#!1980_summer_olympics_boycott': 114,
#  '$#!1980s': 63,
#  '$#!1980s_in_music': 3,
#  '$#!1981_brixton_riot': 19,
#  '$#!1981_major_league_baseball_strike': 3,
#  '$#!1981_milwaukee_brewers_season': 1,
#  '$#!1981_montreal_expos_season': 3,
#  '$#!1981_toxteth_riots': 5,
#  '$#!1982_fifa_world_cup_squads': 1,
#  '$#!1982_hama_massacre': 24,
#  "$#!1982_virginia_vs._chaminade_men's_basketball_game": 2,
#  '$#!1982_washington_redskins_season': 2,
#  '$#!1983_los_angeles_raiders_season': 2,
#  '$#!1983–85_famine_in_ethiopia': 4,
#  '$#!1984_chicago_cubs_season': 1,
#  '$#!1984_san_diego_padres_season': 28,
#  '$#!1984_summer_olympics_boycott': 11,
#  "$#!1984–85_villanova_wildcats_men's_basketball_team": 1,
#  '$#!1985_chicago_bears_season': 3,
#  '$#!1985_los_angeles_dodgers_season': 10,
#  '$#!1985–86_houston_rockets_season': 1,
#  '$#!1986_berlin_discotheque_bombing': 11,
#  '$#!1986_los_angeles_rams_season': 2,
#  '$#!1986_new_york_mets_season': 1,
#  '$#!1986–87_boston_celtics_season': 4,
#  "$#!1987_fijian_coups_d'état": 7,
#  '$#!1987_mecca_incident': 34,
#  '$#!1987_minnesota_twins_season': 4,
#  '$#!1987_st._louis_cardinals_season': 2,
#  '$#!1987_washington_redskins_season': 1,
#  '$#!1987–88_uefa_cup': 4,
#  '$#!1988_los_angeles_rams_season': 2,
#  '$#!1988_october_riots': 2,
#  '$#!1988–89_detroit_pistons_season': 4,
#  '$#!1988–89_los_angeles_lakers_season': 5,
#  "$#!1989_australian_pilots'_dispute": 12,
#  '$#!1989_california_medfly_attack': 1,
#  '$#!1989_indianapolis_500': 2,
#  '$#!1989_riots_in_argentina': 3,
#  '$#!1989_ürümqi_unrest': 2,
#  '$#!1990_back_bay,_massachusetts_train_collision': 1,
#  '$#!1990_chicago_bears_season': 5,
#  '$#!1990_cincinnati_reds_season': 2,
#  '$#!1990_fifa_world_cup': 3,
#  '$#!1990_major_league_baseball_lockout': 27,
#  '$#!1990s': 32,
#  '$#!1990s_in_music': 2,
#  '$#!1991_atlanta_falcons_season': 2,
#  '$#!1991_chicago_bears_season': 1,
#  '$#!1991_detroit_lions_season': 1,
#  '$#!1991_pacific_hurricane_season': 1,
#  '$#!1991_protests_in_belgrade': 24,
#  "$#!1991_soviet_coup_d'état_attempt": 80,
#  '$#!1991_uprisings_in_iraq': 5,
#  "$#!1991–92_european_cup_winners'_cup": 1,
#  '$#!1992_buffalo_bills_season': 1,
#  '$#!1992_cricket_world_cup': 47,
#  '$#!1992_houston_oilers_season': 1,
#  '$#!1992_los_angeles_riots': 20,
#  '$#!1992_nba_finals': 2,
#  '$#!1992_ppg_indy_car_world_series': 2,
#  '$#!1992_summer_olympics': 23,
#  '$#!1992_winter_olympics': 13,
#  "$#!1992–93_european_cup_winners'_cup": 1,
#  '$#!1993_bishopsgate_bombing': 41,
#  '$#!1993_child_sexual_abuse_accusations_against_michael_jackson': 2,
#  '$#!1993_houston_oilers_season': 1,
#  '$#!1993_latur_earthquake': 2,
#  '$#!1993_los_angeles_dodgers_season': 1,
#  '$#!1993_philadelphia_phillies_season': 10,
#  '$#!1993_ramada_hotel_drownings': 77,
#  '$#!1993_world_trade_center_bombing': 27,
#  '$#!1993–94_uefa_champions_league': 2,
#  '$#!1994_nba_finals': 2,
#  '$#!1994_nba_playoffs': 4,
#  '$#!1994_northridge_earthquake': 24,
#  '$#!1994_san_diego_chargers_season': 26,
#  '$#!1994_stanley_cup_finals': 1,
#  '$#!1994_winter_olympics': 38,
#  '$#!1994_winter_olympics_opening_ceremony': 2,
#  '$#!1994–95_danish_superliga': 1,
#  '$#!1994–95_houston_rockets_season': 1,
#  '$#!1994–95_major_league_baseball_strike': 80,
#  '$#!1995_a-league': 3,
#  '$#!1995_atlantic_hurricane_season': 4,
#  '$#!1995_fa_cup_final': 55,
#  '$#!1995_seattle_mariners_season': 5,
#  '$#!1996_nba_playoffs': 1,
#  '$#!1996_summer_olympics': 17,
#  '$#!1997_constitution_of_fiji': 9,
#  '$#!1997_european_grand_prix': 1,
#  '$#!1998_commonwealth_games': 2,
#  '$#!1998_denver_broncos_season': 3,
#  '$#!1998_fifa_world_cup': 115,
#  '$#!1998_fifa_world_cup_qualification_(uefa)': 1,
#  '$#!1998_fifa_world_cup_squads': 1,
#  '$#!1998_united_states_embassy_bombings': 19,
#  '$#!1998_winter_olympics': 95,
#  '$#!1998–2002_argentine_great_depression': 48,
#  '$#!1998–99_nba_lockout': 7,
#  "$#!1999_fifa_women's_world_cup_final": 3,
#  '$#!1999_i̇zmit_earthquake': 2,
#  '$#!1999_new_york_mets_season': 1,
#  '$#!1999_new_york_yankees_season': 1,
#  "$#!1999_pakistani_coup_d'état": 18,
#  '$#!1999_seattle_wto_protests': 33,
#  '$#!1999_washington_redskins_season': 1,
#  '$#!1999–2000_indiana_pacers_season': 1,
#  '$#!19_(adele_album)': 2,
#  '$#!19_(number)': 2,
#  '$#!19th_century': 1,
#  '$#!1_(number)': 657,
#  '$#!1_parachute_battalion': 1,
#  '$#!1_terametre': 11,
#  '$#!1_yottametre': 1,
#  '$#!1c_company': 1,
#  '$#!1st_reconnaissance_squadron': 1,
#  '$#!2,2,2-trichloroethanol': 1,
#  '$#!2,2,4-trimethylpentane': 6,
#  '$#!2,2-dichloro-1,1,1-trifluoroethane': 6,
#  '$#!2,2-dimethoxypropane': 1,
#  '$#!2,3,7,8-tetrachlorodibenzodioxin': 77,
#  '$#!2,3-dichlorophenylpiperazine': 2,
#  '$#!2,4,6-tribromophenol': 47,
#  '$#!2,4,6-trichlorophenol': 1,
#  '$#!2,4-dinitrochlorobenzene': 4,
#  '$#!2,4-dinitrophenol': 13,
#  '$#!2,4-dinitrophenylhydrazine': 4,
#  '$#!2,4-dinitrotoluene': 23,
#  '$#!2,5-dimethoxy-4-bromoamphetamine': 5,
#  '$#!2,5-dimethoxy-4-chloroamphetamine': 112,
#  '$#!2,5-dimethoxy-4-methylamphetamine': 11,
#  '$#!2,6-dichlorobenzonitrile': 3,
#  '$#!2-8-0': 7,
#  '$#!2-8-2': 2,
#  '$#!2-acetylaminofluorene': 4,
#  '$#!2-acetylpyridine': 1,
#  '$#!2-aminopyridine': 1,
#  '$#!2-azetidinone': 1,
#  '$#!2-butoxyethanol': 1,
#  '$#!2-ethoxyethanol': 13,
#  '$#!2-furanone': 9,
#  '$#!2-mercaptopyridine': 5,
#  '$#!2-methyl-2,4-pentanediol': 1,
#  '$#!2-naphthylamine': 20,
#  '$#!2-nitrofluorene': 2,
#  '$#!2-nitroimidazole_nitrohydrolase': 8,
#  '$#!2-phenylphenol': 2,
#  '$#!2-pyrrolidone': 2,
#  '$#!2-vinylpyridine': 6,
#  '$#!2.5d': 1,
#  "$#!2000_fijian_coup_d'état": 6,
#  '$#!2000_nba_playoffs': 1,
#  '$#!2000_oklahoma_sooners_football_team': 1,
#  '$#!2000_summer_olympics': 4,
#  '$#!2000_united_states_census': 54,
#  '$#!2000s_in_fashion': 20,
#  '$#!2000–06_municipal_reorganization_in_quebec': 2,
#  '$#!2001_nba_playoffs': 4,
#  '$#!2001_united_kingdom_foot-and-mouth_outbreak': 5,
#  '$#!2002_american_league_division_series': 1,
#  '$#!2002_bali_bombings': 5,
#  '$#!2002_fifa_world_cup_qualification_(uefa)': 1,
#  '$#!2002_gujarat_riots': 16,
#  '$#!2002_united_states_airtanker_crashes': 1,
#  '$#!2002_winter_olympics': 8,
#  '$#!2003_chicago_cubs_season': 1,
#  '$#!2003_invasion_of_iraq': 491,
#  '$#!2003_national_league_championship_series': 399,
#  '$#!2003_new_england_patriots_season': 1,
#  '$#!2003_new_york_yankees_season': 1,
#  '$#!2003_usc_trojans_football_team': 1,
#  '$#!2003–04_copa_del_rey': 11,
#  '$#!2004_auburn_tigers_football_team': 1,
#  '$#!2004_canadian_figure_skating_championships': 2,
#  '$#!2004_cleveland_browns_season': 1,
#  '$#!2004_indian_ocean_earthquake_and_tsunami': 7,
#  '$#!2004_new_england_patriots_season': 2,
#  '$#!2004_pacific_typhoon_season': 1,
#  '$#!2004_pittsburgh_panthers_football_team': 2,
#  '$#!2004_summer_olympics': 8,
#  '$#!2004_u.s._figure_skating_championships': 4,
#  '$#!2004_utah_utes_football_team': 3,
#  '$#!2004–05_nhl_lockout': 8,
#  '$#!2004–05_uefa_cup': 1,
#  '$#!2005_ashes_series': 1,
#  '$#!2005_base_realignment_and_closure_commission': 2,
#  '$#!2005_french_riots': 5,
#  '$#!2005_houston_astros_season': 12,
#  '$#!2005_kashmir_earthquake': 21,
#  '$#!2005_nba_playoffs': 2,
#  '$#!2005_usc_trojans_football_team': 1,
#  '$#!2005–06_cleveland_cavaliers_season': 4,
#  '$#!2005–06_danish_superliga': 1,
#  '$#!2005–06_nfl_playoffs': 3,
#  '$#!2005–06_uefa_cup': 4,
#  '$#!2006_al-askari_mosque_bombing': 6,
#  '$#!2006_boise_state_broncos_football_team': 1,
#  '$#!2006_commonwealth_games': 6,
#  '$#!2006_detroit_tigers_season': 4,
#  '$#!2006_fifa_world_cup': 34,
#  '$#!2006_fifa_world_cup_officials': 9,
#  '$#!2006_fifa_world_cup_qualification_(uefa)': 8,
#  '$#!2006_hezbollah_cross-border_raid': 26,
#  '$#!2006_lebanon_war': 215,
#  '$#!2006_michigan_state_vs._northwestern_football_game': 1,
#  '$#!2006_nba_playoffs': 1,
#  '$#!2006_ncaa_division_i_fbs_football_rankings': 1,
#  '$#!2006_new_york_mets_season': 24,
#  '$#!2006_new_york_yankees_season': 2,
#  '$#!2006_san_diego_padres_season': 28,
#  '$#!2006_southeast_asian_haze': 2,
#  '$#!2006_southern_leyte_mudslide': 3,
#  "$#!2006_thai_coup_d'état": 28,
#  '$#!2006_united_states_immigration_reform_protests': 10,
#  '$#!2006_winter_olympics_opening_ceremony': 1,
#  '$#!2006–07_copa_del_rey': 68,
#  '$#!2006–07_la_liga': 9,
#  '$#!2006–07_nfl_playoffs': 2,
#  "$#!2006–07_ucla_bruins_men's_basketball_team": 1,
#  '$#!2007_appalachian_state_vs._michigan_football_game': 6,
#  '$#!2007_byu_cougars_football_team': 1,
#  '$#!2007_chinese_export_recalls': 2,
#  '$#!2007_clemson_tigers_football_team': 1,
#  '$#!2007_enlargement_of_the_european_union': 3,
#  '$#!2007_kansas_jayhawks_football_team': 1,
#  '$#!2007_lsu_tigers_football_team': 1,
#  '$#!2007_mid-year_rugby_union_internationals': 3,
#  '$#!2007_national_league_wild_card_tie-breaker_game': 20,
#  '$#!2007_nba_playoffs': 12,
#  '$#!2007_ncaa_division_i_fbs_football_rankings': 1,
#  '$#!2007_new_england_patriots_season': 2,
#  '$#!2007_new_york_giants_season': 4,
#  '$#!2007_rutgers_scarlet_knights_football_team': 1,
#  '$#!2007_san_diego_chargers_season': 1,
#  '$#!2007_san_diego_padres_season': 1,
#  '$#!2007_stanley_cup_finals': 2,
#  '$#!2007_tocopilla_earthquake': 2,
#  '$#!2007_united_kingdom_floods': 3,
#  '$#!2007_wimbledon_championships': 1,
#  '$#!2007–08_copa_del_rey': 1,
#  '$#!2007–08_la_liga': 9,
#  '$#!2007–08_nba_season': 6,
#  '$#!2007–08_nhl_transactions': 1,
#  '$#!2007–08_scottish_premier_league': 1,
#  '$#!2007–08_writers_guild_of_america_strike': 68,
#  '$#!2008_british_grand_prix': 2,
#  '$#!2008_byu_cougars_football_team': 2,
#  '$#!2008_clemson_tigers_football_team': 1,
#  '$#!2008_conflict_in_lebanon': 35,
#  '$#!2008_east_carolina_pirates_football_team': 3,
#  '$#!2008_kosovo_declaration_of_independence': 1,
#  '$#!2008_milwaukee_brewers_season': 1,
#  '$#!2008_mumbai_attacks': 13,
#  '$#!2008_nba_playoffs': 8,
#  '$#!2008_nfl_season': 2,
#  '$#!2008_peru_oil_scandal': 6,
#  '$#!2008_philadelphia_phillies_season': 1,
#  '$#!2008_republican_national_convention': 15,
#  '$#!2008_stanley_cup_finals': 1,
#  '$#!2008_summer_olympics': 750,
#  '$#!2008_summer_olympics_closing_ceremony': 1,
#  '$#!2008_summer_olympics_opening_ceremony': 17,
#  '$#!2008_tibetan_unrest': 70,
#  '$#!2008_uefa_intertoto_cup': 1,
#  '$#!2008_washington_nationals_season': 1,
#  '$#!2008_wimbledon_championships': 6,
#  '$#!2008–09_copa_del_rey': 2,
#  '$#!2008–09_la_liga': 39,
#  '$#!2008–09_nba_season': 140,
#  '$#!2008–09_uefa_cup': 2,
#  '$#!2008–09_zimbabwean_political_negotiations': 24,
#  '$#!2008–11_icelandic_financial_crisis': 78,
#  '$#!2009_afl_finals_series': 1,
#  '$#!2009_byu_cougars_football_team': 1,
#  '$#!2009_clemson_tigers_football_team': 2,
#  '$#!2009_cleveland_browns_season': 1,
#  '$#!2009_copa_libertadores_second_stage': 3,
#  '$#!2009_fifa_confederations_cup': 4,
#  '$#!2009_flu_pandemic': 3,
#  '$#!2009_g-20_pittsburgh_summit': 2,
#  "$#!2009_icc_women's_world_twenty20": 1,
#  '$#!2009_icelandic_financial_crisis_protests': 1,
#  '$#!2009_iranian_presidential_election_protests': 170,
#  '$#!2009_major_league_baseball_season': 15,
#  '$#!2009_mtv_video_music_awards': 8,
#  '$#!2009_nba_finals': 3,
#  '$#!2009_nba_playoffs': 21,
#  '$#!2009_new_england_patriots_season': 1,
#  '$#!2009_nfl_season': 160,
#  '$#!2009_nk_široki_brijeg–fk_sarajevo_football_riots': 1,
#  '$#!2009_pittsburgh_steelers_season': 2,
#  '$#!2009_preakness_stakes': 1,
#  '$#!2009_stanford_cardinal_football_team': 1,
#  '$#!2009_tcu_horned_frogs_football_team': 2,
#  '$#!2009_u.s._state_dinner_security_breaches': 1,
#  '$#!2009_usc_trojans_football_team': 5,
#  '$#!2009_western_athletic_conference_football_season': 1,
#  '$#!2009_wimbledon_championships': 1,
#  '$#!2009_world_baseball_classic': 3,
#  '$#!2009–10_ahl_season': 10,
#  '$#!2009–10_celtic_league': 2,
#  '$#!2009–10_copa_del_rey': 3,
#  '$#!2009–10_coppa_italia': 1,
#  '$#!2009–10_fis_freestyle_skiing_world_cup': 7,
#  '$#!2009–10_irb_sevens_world_series': 1,
#  '$#!2009–10_la_liga': 392,
#  '$#!2009–10_luge_world_cup': 3,
#  '$#!2009–10_nfl_playoffs': 2,
#  '$#!2009–10_nhl_transactions': 2,
#  '$#!2009–10_segunda_división': 1,
#  '$#!2009–10_segunda_división_b': 6,
#  '$#!2009–10_skeleton_world_cup': 8,
#  '$#!2010_asian_games': 1,
#  '$#!2010_auburn_tigers_football_team': 2,
#  '$#!2010_british_grand_prix': 1,
#  '$#!2010_chicago_bears_season': 1,
#  '$#!2010_cincinnati_reds_season': 1,
#  '$#!2010_commonwealth_games_opening_ceremony': 1,
#  '$#!2010_dakar_rally': 1,
#  '$#!2010_eruptions_of_eyjafjallajökull': 2,
#  '$#!2010_european_athletics_championships': 1,
#  '$#!2010_fei_nations_cup_promotional_league': 1,
#  '$#!2010_fifa_club_world_cup': 2,
#  '$#!2010_fifa_world_cup_knockout_stage': 4,
#  '$#!2010_fifa_world_cup_qualification': 2,
#  '$#!2010_fifa_world_cup_qualification_(conmebol)': 1,
#  '$#!2010_fifa_world_cup_qualification_(uefa)': 4,
#  '$#!2010_fifa_world_cup_squads': 12,
#  '$#!2010_haiti_earthquake': 281,
#  '$#!2010_iaaf_diamond_league': 19,
#  "$#!2010_icc_women's_world_twenty20": 1,
#  '$#!2010_monaco_grand_prix': 1,
#  '$#!2010_nascar_sprint_cup_series': 78,
#  '$#!2010_nba_finals': 2,
#  '$#!2010_nba_playoffs': 2,
#  '$#!2010_nfl_season': 19,
#  '$#!2010_northumbria_police_manhunt': 1,
#  '$#!2010_pakistan_floods': 3,
#  '$#!2010_pittsburgh_steelers_season': 2,
#  '$#!2010_stanford_cardinal_football_team': 5,
#  '$#!2010_stanley_cup_playoffs': 5,
#  '$#!2010_tcu_horned_frogs_football_team': 2,
#  '$#!2010_thai_political_protests': 1,
#  '$#!2010_tulsa_golden_hurricane_football_team': 1,
#  '$#!2010_united_states_deepwater_drilling_moratorium': 32,
#  '$#!2010_utep_miners_football_team': 1,
#  '$#!2010_wimbledon_championships': 6,
#  '$#!2010_winter_olympics': 5,
#  '$#!2010_winter_olympics_opening_ceremony': 2,
#  "$#!2010_women's_european_volleyball_league": 1,
#  "$#!2010_women's_national_invitation_tournament": 1,
#  '$#!2010_world_junior_championships_in_athletics': 12,
#  '$#!2010_world_touring_car_championship': 5,
#  '$#!2010s': 23,
#  "$#!2010–11_butler_bulldogs_men's_basketball_team": 1,
#  '$#!2010–11_euroleague': 1,
#  '$#!2010–11_isu_short_track_speed_skating_world_cup': 2,
#  '$#!2010–11_la_liga': 3,
#  '$#!2010–11_memphis_grizzlies_season': 1,
#  '$#!2010–11_nba_season': 3,
#  '$#!2010–11_nhl_transactions': 1,
#  '$#!2010–11_skeleton_world_cup': 12,
#  '$#!2010–11_turkish_cup': 2,
#  '$#!2010–11_uefa_europa_league': 3,
#  '$#!2010–13_big_east_conference_realignment': 2,
#  '$#!2010–14_ncaa_conference_realignment': 65,
#  '$#!2011_afghanistan_ashura_bombings': 2,
#  '$#!2011_asp_world_tour': 4,
#  '$#!2011_byu_cougars_football_team': 1,
#  '$#!2011_championship_league': 1,
#  '$#!2011_england_riots': 6,
#  '$#!2011_european_weightlifting_championships': 4,
#  '$#!2011_fa_wsl': 1,
#  '$#!2011_fifa_u-20_world_cup': 1,
#  "$#!2011_fifa_women's_world_cup_knockout_stage": 1,
#  '$#!2011_fivb_volleyball_world_league': 2,
#  '$#!2011_houston_astros_season': 1,
#  '$#!2011_iaaf_diamond_league': 78,
#  '$#!2011_mercury_insurance_open': 1,
#  '$#!2011_military_intervention_in_libya': 14,
#  '$#!2011_milwaukee_brewers_season': 1,
#  '$#!2011_monaco_grand_prix': 1,
#  '$#!2011_nba_finals': 1,
#  '$#!2011_nba_lockout': 10,
#  '$#!2011_new_york_yankees_season': 1,
#  '$#!2011_nfl_lockout': 6,
#  '$#!2011_nfl_season': 1,
#  '$#!2011_pacific-asia_curling_championships': 11,
#  '$#!2011_pacific_hurricane_season': 1,
#  '$#!2011_rugby_world_cup': 2,
#  '$#!2011_st._louis_cardinals_season': 14,
#  '$#!2011_stanford_cardinal_football_team': 2,
#  '$#!2011_stanley_cup_finals': 5,
#  '$#!2011_tucson_shooting': 17,
#  '$#!2011_tōhoku_earthquake_and_tsunami': 84,
#  '$#!2011_wimbledon_championships': 1,
#  '$#!2011_wisconsin_protests': 4,
#  "$#!2011_women's_national_invitation_tournament": 1,
#  '$#!2011–12_bosnia_and_herzegovina_football_cup': 2,
#  '$#!2011–12_isu_junior_grand_prix': 15,
#  '$#!2011–12_jordanian_protests': 1,
#  '$#!2011–12_la_liga': 16,
#  '$#!2011–12_nba_season': 2,
#  '$#!2011–12_premier_league': 22,
#  '$#!2011–12_uefa_champions_league_knockout_phase': 5,
#  '$#!2011–13_russian_protests': 7,
#  '$#!2012_africa_cup_of_nations': 1,
#  '$#!2012_aurora_shooting': 28,
#  '$#!2012_davis_cup_world_group': 38,
#  '$#!2012_hama_offensive': 21,
#  '$#!2012_homs_offensive': 3,
#  '$#!2012_masters_tournament': 3,
#  '$#!2012_nba_playoffs': 6,
#  '$#!2012_nfl_season': 2,
#  '$#!2012_stanley_cup_finals': 1,
#  '$#!2012_summer_olympics': 29,
#  '$#!2012_summer_olympics_and_paralympics_cauldron': 2,
#  '$#!2012_summer_olympics_closing_ceremony': 23,
#  '$#!2012_summer_olympics_opening_ceremony': 38,
#  '$#!2012_summer_paralympics_opening_ceremony': 1,
#  '$#!2012_wimbledon_championships': 5,
#  '$#!2012–13_copa_del_rey': 2,
#  '$#!2012–13_egyptian_protests': 4,
#  '$#!2012–13_football_league_cup': 15,
#  "$#!2012–13_men's_fih_hockey_world_league_semifinals": 1,
#  '$#!2012–13_nhl_lockout': 8,
#  '$#!2012–13_odense_boldklub_season': 1,
#  '$#!2012–13_pba_philippine_cup_finals': 1,
#  '$#!2012–13_uefa_europa_league': 3,
#  '$#!2012–13_uefa_europa_league_knockout_phase': 1,
#  '$#!2013_auburn_tigers_football_team': 3,
#  '$#!2013_buffalo_bills_season': 6,
#  '$#!2013_bulgarian_protests_against_the_first_borisov_cabinet': 1,
#  '$#!2013_cincinnati_bengals_season': 2,
#  '$#!2013_cincinnati_reds_season': 17,
#  '$#!2013_dallas_cowboys_season': 8,
#  '$#!2013_denver_broncos_season': 4,
#  "$#!2013_egyptian_coup_d'état": 47,
#  '$#!2013_enlargement_of_the_european_union': 8,
#  '$#!2013_green_bay_packers_season': 1,
#  '$#!2013_indianapolis_colts_season': 1,
#  '$#!2013_kansas_city_chiefs_season': 6,
#  '$#!2013_lahad_datu_standoff': 13,
#  '$#!2013_los_angeles_international_airport_shooting': 2,
#  '$#!2013_naxal_attack_in_darbha_valley': 1,
#  '$#!2013_new_england_patriots_season': 11,
#  '$#!2013_new_orleans_saints_season': 4,
#  '$#!2013_norwegian_football_cup': 1,
#  '$#!2013_san_diego_chargers_season': 5,
#  '$#!2013_seattle_seahawks_season': 3,
#  '$#!2013_segunda_división_b_play-offs': 8,
#  '$#!2013_southern_california_open': 3,
#  '$#!2013_stanford_cardinal_football_team': 1,
#  '$#!2013_stanley_cup_finals': 14,
#  '$#!2013_tampa_bay_buccaneers_season': 4,
#  '$#!2013_washington_redskins_season': 1,
#  '$#!2013_wimbledon_championships': 1,
#  '$#!2013–14_coppa_italia': 2,
#  '$#!2013–14_la_liga': 1,
#  '$#!2013–14_nfl_playoffs': 5,
#  '$#!2013–14_segunda_división': 2,
#  '$#!2013–14_uefa_champions_league': 14,
#  '$#!2014_atlanta_falcons_season': 1,
#  '$#!2014_brit_awards': 147,
#  '$#!2014_campeonato_brasileiro_série_a': 6,
#  '$#!2014_cfl_season': 2,
#  '$#!2014_cincinnati_reds_season': 1,
#  '$#!2014_college_basketball_invitational': 1,
#  '$#!2014_collegeinsider.com_postseason_tournament': 10,
#  '$#!2014_denver_broncos_season': 9,
#  '$#!2014_fatah–hamas_agreements': 208,
#  '$#!2014_fifa_club_world_cup': 2,
#  '$#!2014_fifa_world_cup': 3,
#  '$#!2014_fifa_world_cup_knockout_stage': 3,
#  '$#!2014_fifa_world_cup_qualification_(concacaf)': 2,
#  '$#!2014_fifa_world_cup_qualification_–_uefa_second_round': 5,
#  '$#!2014_grozny_clashes': 4,
#  '$#!2014_hong_kong_protests': 33,
#  '$#!2014_isla_vista_killings': 14,
#  '$#!2014_israel–gaza_conflict': 256,
#  '$#!2014_jinnah_international_airport_attack': 2,
#  '$#!2014_los_angeles_dodgers_season': 38,
#  '$#!2014_masters_tournament': 1,
#  '$#!2014_nba_finals': 2,
#  '$#!2014_nebraska_cornhuskers_football_team': 8,
#  '$#!2014_new_england_patriots_season': 2,
#  '$#!2014_rose_bowl': 3,
#  '$#!2014_san_francisco_giants_season': 3,
#  '$#!2014_segunda_división_b_play-offs': 2,
#  '$#!2014_shootings_at_parliament_hill,_ottawa': 5,
#  '$#!2014_singapore_cup': 1,
#  '$#!2014_sydney_hostage_crisis': 44,
#  '$#!2014_toronto_international_film_festival': 1,
#  '$#!2014_washington_redskins_season': 9,
#  '$#!2014_wimbledon_championships': 3,
#  '$#!2014_winter_olympics': 24,
#  '$#!2014–15_a_group': 4,
#  '$#!2014–15_cleveland_cavaliers_season': 7,
#  '$#!2014–15_copa_del_rey': 4,
#  '$#!2014–15_dallas_mavericks_season': 3,
#  '$#!2014–15_danish_superliga': 2,
#  '$#!2014–15_la_liga': 6,
#  '$#!2014–15_nhl_transactions': 1,
#  '$#!2014–15_segunda_división': 6,
#  '$#!2014–15_segunda_división_b': 1,
#  '$#!2014–15_uefa_champions_league': 14,
#  '$#!2014–16_venezuelan_protests': 4,
#  '$#!2015_afc_asian_cup_knockout_stage': 2,
#  '$#!2015_afc_asian_cup_qualification': 1,
#  '$#!2015_baltimore_protests': 2,
#  '$#!2015_bangkok_bombing': 1,
#  '$#!2015_chicago_cubs_season': 15,
#  '$#!2015_cincinnati_bengals_season': 6,
#  '$#!2015_clemson_tigers_football_team': 1,
#  '$#!2015_cleveland_browns_season': 3,
#  '$#!2015_collegeinsider.com_postseason_tournament': 4,
#  '$#!2015_copenhagen_shootings': 5,
#  '$#!2015_denver_broncos_season': 2,
#  '$#!2015_grand_prix_sar_la_princesse_lalla_meryem': 7,
#  '$#!2015_interim_election_government_of_turkey': 70,
#  '$#!2015_kansas_city_royals_season': 1,
#  '$#!2015_leytonstone_tube_station_attack': 1,
#  '$#!2015_los_angeles_dodgers_season': 1,
#  '$#!2015_ma–xi_meeting': 6,
#  "$#!2015_mcdonald's_burnie_international": 1,
#  '$#!2015_miami_dolphins_season': 1,
#  '$#!2015_milwaukee_brewers_season': 4,
#  '$#!2015_mina_stampede': 1,
#  '$#!2015_national_invitation_tournament': 1,
#  '$#!2015_nba_finals': 3,
#  '$#!2015_new_york_jets_season': 14,
#  '$#!2015_nfl_season': 2,
#  '$#!2015_pacific_hurricane_season': 1,
#  '$#!2015_rugby_world_cup_pool_a': 2,
#  '$#!2015_rugby_world_cup_–_americas_qualification': 5,
#  '$#!2015_san_diego_padres_season': 1,
#  '$#!2015_st._louis_cardinals_season': 1,
#  '$#!2015_st._louis_rams_season': 13,
#  '$#!2015_wimbledon_championships': 1,
#  '$#!2015–16_atlanta_hawks_season': 1,
#  '$#!2015–16_brooklyn_nets_season': 2,
#  '$#!2015–16_charlotte_hornets_season': 2,
#  '$#!2015–16_concacaf_champions_league_knockout_stage': 2,
#  '$#!2015–16_dallas_mavericks_season': 4,
#  '$#!2015–16_denver_nuggets_season': 1,
#  '$#!2015–16_detroit_pistons_season': 4,
#  "$#!2015–16_furman_paladins_men's_basketball_team": 1,
#  '$#!2015–16_houston_rockets_season': 3,
#  '$#!2015–16_miami_heat_season': 1,
#  '$#!2015–16_nhl_transactions': 8,
#  '$#!2015–16_orlando_magic_season': 1,
#  "$#!2015–16_pepperdine_waves_men's_basketball_team": 2,
#  '$#!2015–16_portland_trail_blazers_season': 1,
#  '$#!2015–16_utah_jazz_season': 2,
#  '$#!2016_college_basketball_invitational': 2,
#  '$#!2016_denver_broncos_season': 1,
#  '$#!2016_nrl_season': 7,
#  '$#!2016_summer_paralympics': 1,
#  '$#!2020_summer_olympics': 12,
#  '$#!2060_chiron': 10,
#  '$#!20_(number)': 103,
#  '$#!20_july_plot': 17,
#  '$#!20_y.o.': 5,
#  '$#!20th_century': 1,
#  '$#!20th_century_fox': 281,
#  '$#!20th_united_states_congress': 2,
#  '$#!20th_waffen_grenadier_division_of_the_ss_(1st_estonian)': 3,
#  '$#!21-gun_salute': 7,
#  '$#!2112_(album)': 7,
#  '$#!21_(drinking_game)': 1,
#  '$#!22_bishopsgate': 3,
#  '$#!2340_hathor': 1,
#  '$#!23rd_waffen_mountain_division_of_the_ss_kama_(2nd_croatian)': 1,
#  '$#!23s_rrna_(adenine1618-n6)-methyltransferase': 1,
#  '$#!24-hour_clock': 11,
#  '$#!243_ida': 1,
#  '$#!24_(number)': 1,
#  '$#!24_(tv_series)': 4,
#  '$#!24_caprices_for_solo_violin_(paganini)': 1,
#  '$#!24_hours_of_daytona': 1,
#  '$#!24_hours_of_le_mans': 2,
#  '$#!24_hours_of_lemons': 1,
#  '$#!25_meter_center-fire_pistol': 2,
#  '$#!28_weeks_later': 1,
#  '$#!2_(number)': 455,
#  '$#!2_chainz_discography': 1,
#  '$#!2_cold_scorpio': 3,
#  '$#!2_pallas': 1,
#  '$#!2c-i': 5,
#  '$#!2d_computer_graphics': 24,
#  '$#!2k11_krug': 5,
#  '$#!2k12_kub': 9,
#  '$#!2k22_tunguska': 58,
#  '$#!2nd_(the_rasmus_ep)': 1,
#  '$#!2nd_foreign_parachute_regiment': 1,
#  '$#!2nd_guards_tamanskaya_motor_rifle_division': 3,
#  '$#!2nd_united_states_congress': 1,
#  '$#!2s19_msta': 10,
#  '$#!2s3_akatsiya': 1,
#  '$#!2s4_tyulpan': 4,
#  '$#!2s5_giatsint-s': 4,
#  "$#!3,3',5,5'-tetramethylbenzidine": 1,
#  "$#!3,3'-dichlorobenzidine": 17,
#  '$#!3,4-methylenedioxy-n-hydroxy-n-methylamphetamine': 6,
#  '$#!3-(trifluoromethyl)aniline': 7,
#  '$#!3-amino-1,2,4-triazole': 1,
#  '$#!3-chloropropionitrile': 12,
#  '$#!3-hydroxy-9,10-secoandrosta-1,3,5(10)-triene-9,17-dione_monooxygenase': 5,
#  ...}

# %% [markdown]
# Now i wanna see the proportion of concept who occurs less than 5 times

# %%
cpt=0
for k in dico_concept : 
    if dico_concept[k] < 5:
        cpt+=1

print(round((cpt/len(dico_concept))*100,2),"% of the concept appears less than 5 times.")
# Out:
# 64.15 % of the concept appears less than 5 times.

# %%
def delete_low_frq(ad,ac,dico_concept):
    delete = []
    for k in dico_concept: 
        if dico_concept[k]<5:
            delete.append(k)
    
    for k in ad:
        for m in ad[k]:
            if m in delete:
                ad[k].remove(m)
                ac[k].remove(m)
    return ad,ac

# %% [markdown]
# In most paper, we should have more than 5 occurrences of a word to learn a good representation of it. However in this case, the majority of concepts appears less than this number so we will try differents methods to resolve this prob.

# %% [markdown]
# ## Learning part with W2V

# %% [markdown]
# ### Try with low frequency concept anyway...

# %% [markdown]
# In this part we will try to learn the representation without removing the low frequency concept.

# %%
"""               PARAMETERS                  """

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 1 # Usually is 5 But in this case we will try to learn even for a word that occurs 1 time

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 30 # Some concept are really long and we want to catch other concept in the window
                  # So we put a large context_size.

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
allRobustConcept2v = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling,
)

# %%
allRobustConcept2v.build_vocab(list(ad.values())) # We need list of sentences (doc)

# %%
print("Word2Vec vocabulary length:", len(allRobustConcept2v.wv.vocab))
# Out:
# Word2Vec vocabulary length: 792756

# %% [markdown]
# #### Training

# %%
allRobustConcept2v.train(list(ad.values()),total_examples=allRobustConcept2v.corpus_count,epochs=7)
# Out:
# (989606702, 1001807443)

# %%
pathw2v = "/local/karmim/Stage_M1_RI/data/object_python/concept_part"
path_all_concept = os.path.join(pathw2v, "allRobustConcept2v.w2v")
allRobustConcept2v.save(path_all_concept)
# Out:
# /home/karmim/envs/my_env/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
allRobustConcept2v.wv.most_similar('$#!risk', topn=10)
# Out:
# [('risks', 0.9223514795303345),
#  ('risk', 0.8827913999557495),
#  ('danger', 0.7749564051628113),
#  ('dangers', 0.7668755650520325),
#  ('dangerous', 0.7022541761398315),
#  ('potentially', 0.6876526474952698),
#  ('risky', 0.6718818545341492),
#  ('exposure', 0.6668649911880493),
#  ('exposed', 0.6455274820327759),
#  ('greater', 0.6365047693252563)]

# %%
allRobustConcept2v.wv.most_similar('$#!international', topn=10) # Not really nice...
# Out:
# [('$#!andy_reed_(rugby_union)', 0.5546355247497559),
#  ('intl', 0.554165244102478),
#  ('$#!jimmy_baxter_(basketball)', 0.5525927543640137),
#  ('mandain', 0.5486284494400024),
#  ('$#!paessler_router_traffic_grapher', 0.548347532749176),
#  ('dvlpt', 0.5477840900421143),
#  ('$#!lionheart_(comics)', 0.5476211905479431),
#  ('japn', 0.5429699420928955),
#  ('transcomms', 0.5429620146751404),
#  ('trininty', 0.5423702001571655)]

# %%
allRobustConcept2v.wv.most_similar('$#!beauty', topn=10)
# Out:
# [('beauty', 0.8481885194778442),
#  ('beautiful', 0.6803887486457825),
#  ('aesthetic', 0.6532540321350098),
#  ('$#!milarepa', 0.608664870262146),
#  ('$#!the_touch_(2002_film)', 0.6047132015228271),
#  ('discursiveness', 0.6024684906005859),
#  ('impressionnisme', 0.6017350554466248),
#  ('mosaicists', 0.5994110703468323),
#  ('sensual', 0.5985092520713806),
#  ('urbanities', 0.5976210832595825)]

# %%
allRobustConcept2v.wv.most_similar('trafic', topn=10)
# Out:
# [('$#!renault_trafic', 0.8822504878044128),
#  ('$#!xiaogan', 0.7465230226516724),
#  ('jettas', 0.7232366800308228),
#  ('$#!sipani', 0.7162378430366516),
#  ('sipani', 0.7063448429107666),
#  ('$#!société_des_usines_chausson', 0.6881568431854248),
#  ('ciezarowych', 0.6837400197982788),
#  ('batilly', 0.6835135221481323),
#  ('heuliez', 0.6811609268188477),
#  ('$#!toyota_land_cruiser', 0.67405104637146)]

# %%
allRobustConcept2v.wv.most_similar('france', topn=10)
# Out:
# [('$#!france', 0.9830839037895203),
#  ('french', 0.7742928266525269),
#  ('$#!france_national_football_team', 0.750748872756958),
#  ('paris', 0.7189632654190063),
#  ('italy', 0.6941613554954529),
#  ('$#!paris', 0.6804600954055786),
#  ('$#!french_poetry', 0.6797875165939331),
#  ('britain', 0.6785295009613037),
#  ('$#!germany', 0.6755388379096985),
#  ('$#!italy', 0.6731325387954712)]

# %%
allRobustConcept2v.wv.most_similar('bush', topn=10)
# Out:
# [('$#!george_w._bush', 0.9117322564125061),
#  ('$#!george_h._w._bush', 0.7876810431480408),
#  ('administration', 0.7690497636795044),
#  ('$#!bush_(band)', 0.7602911591529846),
#  ('reagan', 0.7442588806152344),
#  ('$#!president_of_the_united_states', 0.7436239719390869),
#  ('fitzwater', 0.7412006855010986),
#  ('congress', 0.7260851860046387),
#  ('sununu', 0.6991183757781982),
#  ('$#!united_states_congress', 0.6896796822547913)]

# %% [markdown]
# It seems to work pretty good, even with the low frequency concept ! Now i'll relaunch another training on the most frequent concept.

# %%
dico_concept['$#!george_w._bush']
# Out:
# 3872

# %%
# Count how much terms of the querys are not in the allRobustConcept2v model.
nb_word = 0
cpt = 0
for k in q : 
    for w in q[k]:
        nb_word +=1
        if w not in allRobustConcept2v :

            cpt+=1
                
print(round((cpt/nb_word)*100,2),"terms of the query are not in the model")
# Out:
# 18.14 terms of the query are not in the model
# /home/karmim/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   import sys

# %% [markdown]
# ### Remove low frequency terms and concepts

# %%
"""
num_features = 300
min_word_count = 5 
num_workers = multiprocessing.cpu_count()
context_size = 30 
downsampling = 1e-3
seed = 1

allRobustConcept2v = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling,
    )
    
    allRobustConcept2v.build_vocab(list(ad.values())) # We need list of sentences (doc) 
    print("Building vocabulary, done.")
    allRobustConcept2v.train(list(ad.values()),total_examples=allRobustConcept2v.corpus_count,epochs=7)
    print("Training model, done.")
    allRobustConcept2v.save(path_all_concept)
"""
# Out:
# 'allRobustConcept2v = w2v.Word2Vec(\n    sg=1,\n    seed=seed,\n    workers=num_workers,\n    size=num_features,\n    min_count=min_word_count,\n    window=context_size,\n    sample=downsampling,\n)'

# %% [markdown]
# ### PPMI

# %% [markdown]
# Now we'll use a metric called PPMI to face the problem of low frequency occurences of some of the concept in our dataset.
#
# https://en.wikipedia.org/wiki/Pointwise_mutual_information

# %% [markdown]
# ## Some visualisations

# %%
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0) # We'll try to visualize our data in 2D with a T-SNE.

# %%
all_word_vectors_matrix = allRobustConcept2v.wv.vectors

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[allRobustConcept2v.wv.vocab[word].index])
            for word in allRobustConcept2v.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)
